# %% [markdown]
# ## 신용카드 사용자 연체 예측 AI 경진대회

# %% [markdown]
# ### 데이터 변수
#  - gender: 성별
#  - car: 차량 소유 여부
#  - reality : 부동산 소유 여부
#  - child num: 자녀 수
#  - income_total : 연간 소득
#  - income_type : 소득 분류=> ['Commercial associate', 'Working', 'State servant', 'Pensioner', 'Student']
#  - edu_type : 교육 수준 => ['Higher education' ,'Secondary / secondary special', 'Incomplete higher', 'Lower secondary', 'Academic degree']
#  - family_type: 결혼 여부 => ['Married', 'Civil marriage', 'Separated', 'Single / not married', 'Widow']
#  - house_type: 생활방식 => ['Municipal apartment', 'House / apartment', 'With parents','Co-op apartment', 'Rented apartment', 'Office apartment']
#  - day_birth: 출생일 =>-1은 데이터 수집일 하루 전 출생,데이터수집당시 0으로부터 역으로 셈(하루단위)
#  - day_employed: 업무 시작일. 하루단위로 계산. 양수는 고용x
#  - flag_mobil: 휴대폰 소유 여부
#  - work_phone: 업무용 전화 소유 여부
#  - phone: 전화 소유 여부
#  - email: 이메일 소유 여부
#  - occyp_type: 직업 유형
#  - family_size: 가족 규모
#  - begin_month: 신용카드 발급월
#
# 종속변수 (credit) : 사용자의 신용카드 대금 연체를 기준으로 한 신용도. 낮을수록 높은 신용의 신용카드 사용자를 의미

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd   
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import plot_importance
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import f1_score
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
from lightgbm import plot_importance

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
submit=pd.read_csv('sample_submission.csv')
df_train=train.copy()
df_test=test.copy()

# %%
train.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0      -13899          -4709           1           0      0      0
# 1      -11380          -1540           1           0      0      1
# 2      -19087          -4434           1           0      1      0
# 3      -15088          -2092           1           0      1      0
# 4      -15037          -2105           1           0      0      0
#
#     occyp_type  family_size  begin_month  credit
# 0          NaN          2.0         -6.0     1.0
# 1     Laborers          3.0         -5.0     1.0
# 2     Managers          2.0        -22.0     2.0
# 3  Sales staff          2.0        -37.0     0.0
# 4     Managers          2.0        -26.0     2.0

# %%
test.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0  26457      M   Y       N          0      112500.0             Pensioner
# 1  26458      F   N       Y          0      135000.0         State servant
# 2  26459      F   N       Y          0       69372.0               Working
# 3  26460      M   Y       N          0      112500.0  Commercial associate
# 4  26461      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0      -21990         365243           1           0      1      0
# 1      -18964          -8671           1           0      1      0
# 2      -15887           -217           1           1      1      0
# 3      -19270          -2531           1           1      0      0
# 4      -17822          -9385           1           1      0      0
#
#    occyp_type  family_size  begin_month
# 0         NaN          2.0        -60.0
# 1  Core staff          2.0        -36.0
# 2    Laborers          2.0        -40.0
# 3     Drivers          2.0        -41.0
# 4    Managers          2.0         -8.0

# %%
print(train.shape,test.shape)
# Out:
# (26457, 20) (10000, 19)

# %%
train.info() #occyp_type만 결측값 존재
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
# index            26457 non-null int64
# gender           26457 non-null object
# car              26457 non-null object
# reality          26457 non-null object
# child_num        26457 non-null int64
# income_total     26457 non-null float64
# income_type      26457 non-null object
# edu_type         26457 non-null object
# family_type      26457 non-null object
# house_type       26457 non-null object
# DAYS_BIRTH       26457 non-null int64
# DAYS_EMPLOYED    26457 non-null int64
# FLAG_MOBIL       26457 non-null int64
# work_phone       26457 non-null int64
# phone            26457 non-null int64
# email            26457 non-null int64
# occyp_type       18286 non-null object
# family_size      26457 non-null float64
# begin_month      26457 non-null float64
# credit           26457 non-null float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 4.0+ MB

# %% [markdown]
# ### 결측치 확인

# %%
#결측치 제거
train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %%
train['occyp_type'].value_counts().plot(kind='bar')
#laborers가 많은 편. core staff, sales staff,managers,drivers 순으로 나타남
#노동자들이 많은 타입

# %%
train['occyp_type'].value_counts()
# Out:
# Laborers                 4512
# Core staff               2646
# Sales staff              2539
# Managers                 2167
# Drivers                  1575
# High skill tech staff    1040
# Accountants               902
# Medicine staff            864
# Cooking staff             457
# Security staff            424
# Cleaning staff            403
# Private service staff     243
# Low-skill Laborers        127
# Waiters/barmen staff      124
# Secretaries                97
# Realty agents              63
# HR staff                   62
# IT staff                   41
# Name: occyp_type, dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 결측치 분석

# %%
non_occyp=df_train.loc[df_train['occyp_type'].isnull()]#직업유형이 없는 사람
occyp=df_train.dropna()#직업유형이 있는 사람(결측치 제거)

# %%
non_occyp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8171 entries, 0 to 26453
# Data columns (total 20 columns):
# index            8171 non-null int64
# gender           8171 non-null object
# car              8171 non-null object
# reality          8171 non-null object
# child_num        8171 non-null int64
# income_total     8171 non-null float64
# income_type      8171 non-null object
# edu_type         8171 non-null object
# family_type      8171 non-null object
# house_type       8171 non-null object
# DAYS_BIRTH       8171 non-null int64
# DAYS_EMPLOYED    8171 non-null int64
# FLAG_MOBIL       8171 non-null int64
# work_phone       8171 non-null int64
# phone            8171 non-null int64
# email            8171 non-null int64
# occyp_type       0 non-null object
# family_size      8171 non-null float64
# begin_month      8171 non-null float64
# credit           8171 non-null float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 1.3+ MB

# %%
non_occyp.head() #occyp_type이 없는 사람
# Out:
#     index gender car reality  child_num  income_total           income_type  \
# 0       0      F   N       N          0      202500.0  Commercial associate
# 8       8      M   Y       Y          1      180000.0  Commercial associate
# 14     14      F   N       Y          0      157500.0             Pensioner
# 18     18      F   N       Y          0      216000.0             Pensioner
# 19     19      F   N       Y          0      180000.0               Working
#
#                          edu_type           family_type           house_type  \
# 0                Higher education               Married  Municipal apartment
# 8                Higher education               Married    House / apartment
# 14  Secondary / secondary special  Single / not married    House / apartment
# 18  Secondary / secondary special               Married    House / apartment
# 19  Secondary / secondary special               Married    House / apartment
#
#     DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0       -13899          -4709           1           0      0      0
# 8       -15131          -1466           1           0      0      1
# 14      -22922         365243           1           0      1      0
# 18      -23113         365243           1           0      0      0
# 19      -13727          -6031           1           0      0      0
#
#    occyp_type  family_size  begin_month  credit
# 0         NaN          2.0         -6.0     1.0
# 8         NaN          3.0        -38.0     2.0
# 14        NaN          1.0        -41.0     2.0
# 18        NaN          2.0        -37.0     2.0
# 19        NaN          2.0         -7.0     2.0

# %%
occyp.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
# 5      5      F   N       Y          2      270000.0               Working
#
#                         edu_type     family_type         house_type  \
# 1  Secondary / secondary special  Civil marriage  House / apartment
# 2               Higher education         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
# 5  Secondary / secondary special         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 1      -11380          -1540           1           0      0      1
# 2      -19087          -4434           1           0      1      0
# 3      -15088          -2092           1           0      1      0
# 4      -15037          -2105           1           0      0      0
# 5      -13413          -4996           1           0      0      1
#
#               occyp_type  family_size  begin_month  credit
# 1               Laborers          3.0         -5.0     1.0
# 2               Managers          2.0        -22.0     2.0
# 3            Sales staff          2.0        -37.0     0.0
# 4               Managers          2.0        -26.0     2.0
# 5  High skill tech staff          4.0        -18.0     1.0

# %%
occyp.loc[occyp['DAYS_EMPLOYED']>0]#1이 없음
#전부다 고용된 상태임
# Out:
# Empty DataFrame
# Columns: [index, gender, car, reality, child_num, income_total, income_type, edu_type, family_type, house_type, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, work_phone, phone, email, occyp_type, family_size, begin_month, credit]
# Index: []

# %%
non_occyp['DAYS_EMPLOYED'].value_counts()
#양수인 부분이 4438개->고용된 사람과 그렇지 않은 사람이 존재한다.
# Out:
#  365243    4438
# -302         25
# -1613        21
# -2014        21
# -3079        21
# -5639        20
# -1751        20
# -137         19
# -5521        16
# -1315        16
# -135         15
# -4834        15
# -229         14
# -2339        14
# -3322        14
# -2501        14
# -15038       14
# -2654        13
# -1202        13
# -170         13
# -469         13
# -422         13
# -7627        13
# -3458        12
# -1160        12
# -1113        12
# -3668        12
# -901         12
# -4943        12
# -2065        12
#            ...
# -4089         1
# -7953         1
# -5910         1
# -1844         1
# -3592         1
# -2074         1
# -3935         1
# -1892         1
# -1904         1
# -3967         1
# -3999         1
# -5866         1
# -3604         1
# -184          1
# -5754         1
# -5706         1
# -1620         1
# -1640         1
# -1644         1
# -1648         1
# -1656         1
# -917          1
# -2870         1
# -1680         1
# -7738         1
# -873          1
# -4029         1
# -825          1
# -3608         1
# -2051         1
# Name: DAYS_EMPLOYED, Length: 963, dtype: int64

# %%
non_occyp['employeed']=[1 if t<0 else 0 for t in list(non_occyp['DAYS_EMPLOYED'])]

# %%
non_occyp.head()#양수면 0,음수면 1
# Out:
#     index gender car reality  child_num  income_total           income_type  \
# 0       0      F   N       N          0      202500.0  Commercial associate
# 8       8      M   Y       Y          1      180000.0  Commercial associate
# 14     14      F   N       Y          0      157500.0             Pensioner
# 18     18      F   N       Y          0      216000.0             Pensioner
# 19     19      F   N       Y          0      180000.0               Working
#
#                          edu_type           family_type           house_type  \
# 0                Higher education               Married  Municipal apartment
# 8                Higher education               Married    House / apartment
# 14  Secondary / secondary special  Single / not married    House / apartment
# 18  Secondary / secondary special               Married    House / apartment
# 19  Secondary / secondary special               Married    House / apartment
#
#     ...  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  occyp_type  \
# 0   ...          -4709           1           0      0      0         NaN
# 8   ...          -1466           1           0      0      1         NaN
# 14  ...         365243           1           0      1      0         NaN
# 18  ...         365243           1           0      0      0         NaN
# 19  ...          -6031           1           0      0      0         NaN
#
#    family_size  begin_month  credit  employeed
# 0          2.0         -6.0     1.0          1
# 8          3.0        -38.0     2.0          1
# 14         1.0        -41.0     2.0          0
# 18         2.0        -37.0     2.0          0
# 19         2.0         -7.0     2.0          1
#
# [5 rows x 21 columns]

# %%
occyp['employeed']=1

# %%
occyp.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
# 5      5      F   N       Y          2      270000.0               Working
#
#                         edu_type     family_type         house_type  ...  \
# 1  Secondary / secondary special  Civil marriage  House / apartment  ...
# 2               Higher education         Married  House / apartment  ...
# 3  Secondary / secondary special         Married  House / apartment  ...
# 4               Higher education         Married  House / apartment  ...
# 5  Secondary / secondary special         Married  House / apartment  ...
#
#    DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email             occyp_type  \
# 1          -1540           1           0      0      1               Laborers
# 2          -4434           1           0      1      0               Managers
# 3          -2092           1           0      1      0            Sales staff
# 4          -2105           1           0      0      0               Managers
# 5          -4996           1           0      0      1  High skill tech staff
#
#   family_size  begin_month  credit  employeed
# 1         3.0         -5.0     1.0          1
# 2         2.0        -22.0     2.0          1
# 3         2.0        -37.0     0.0          1
# 4         2.0        -26.0     2.0          1
# 5         4.0        -18.0     1.0          1
#
# [5 rows x 21 columns]

# %% [markdown]
# 결측치에 해당하는 값을 조사한 결과 고용이 안 된 사람과 된 사람 모두 포함되지만 결측값이 없는 상태는 모두 고용이 된 사람들이다.

# %%
#결측값 중 고용된 사람 중에서 소득분류 분포
non_occyp.loc[non_occyp['employeed']==1]['income_type'].value_counts()
# Out:
# Working                 2312
# Commercial associate    1026
# State servant            392
# Pensioner                  2
# Student                    1
# Name: income_type, dtype: int64

# %% [markdown]
# 일하는 사람은 2312,상업 제휴를 하는 사람은 1026,공무원은 392,학생은 1명,연금수령자는 2명(2명은 정년퇴직?)

# %%
non_occyp.loc[non_occyp['DAYS_EMPLOYED']>=0]['income_type'].value_counts()
#고용되지 않은 사람 중에는 연금을 수령한 사람들이다.
# Out:
# Pensioner    4438
# Name: income_type, dtype: int64

# %%
print(occyp.shape,non_occyp.shape)
# Out:
# (18286, 21) (8171, 21)

# %%
non_occyp.loc[(non_occyp['employeed']==0)] #4438개,고용되지 않은 사람 수
# Out:
#        index gender car reality  child_num  income_total income_type  \
# 14        14      F   N       Y          0      157500.0   Pensioner
# 18        18      F   N       Y          0      216000.0   Pensioner
# 21        21      F   N       N          0      157500.0   Pensioner
# 24        24      F   N       N          0      202500.0   Pensioner
# 46        46      F   N       N          0      135000.0   Pensioner
# 48        48      F   N       Y          0       99000.0   Pensioner
# 52        52      F   N       Y          0       54000.0   Pensioner
# 58        58      F   N       Y          0      144000.0   Pensioner
# 59        59      F   N       Y          0      360000.0   Pensioner
# 60        60      M   Y       Y          0      112500.0   Pensioner
# 73        73      F   N       Y          0      180000.0   Pensioner
# 84        84      M   Y       Y          0      135000.0   Pensioner
# 94        94      F   N       Y          0      180000.0   Pensioner
# 95        95      M   N       Y          0       79650.0   Pensioner
# 115      115      F   N       N          0       81000.0   Pensioner
# 120      120      F   N       Y          0      157500.0   Pensioner
# 134      134      F   Y       Y          0      135000.0   Pensioner
# 138      138      F   N       Y          0       54000.0   Pensioner
# 155      155      F   N       Y          0       90000.0   Pensioner
# 159      159      F   N       Y          0      153000.0   Pensioner
# 163      163      F   N       Y          0      155250.0   Pensioner
# 166      166      F   N       Y          0      495000.0   Pensioner
# 173      173      F   N       Y          0      189000.0   Pensioner
# 178      178      M   N       N          0      126000.0   Pensioner
# 181      181      F   N       Y          0       90000.0   Pensioner
# 183      183      F   N       Y          0      157500.0   Pensioner
# 188      188      F   N       N          0      112500.0   Pensioner
# 190      190      F   N       Y          0       90000.0   Pensioner
# 191      191      F   N       N          0      121500.0   Pensioner
# 209      209      F   N       Y          0       81000.0   Pensioner
# ...      ...    ...  ..     ...        ...           ...         ...
# 26262  26262      F   N       Y          0      184500.0   Pensioner
# 26263  26263      F   N       Y          0      180000.0   Pensioner
# 26266  26266      F   Y       Y          0      270000.0   Pensioner
# 26279  26279      F   N       Y          0       81000.0   Pensioner
# 26283  26283      F   Y       N          0       90000.0   Pensioner
# 26291  26291      F   N       Y          0      180000.0   Pensioner
# 26321  26321      F   N       Y          0       94500.0   Pensioner
# 26325  26325      F   N       Y          0       67500.0   Pensioner
# 26329  26329      F   N       Y          0      225000.0   Pensioner
# 26334  26334      F   N       Y          0      112500.0   Pensioner
# 26341  26341      F   N       Y          0       47250.0   Pensioner
# 26361  26361      F   N       Y          0      202500.0   Pensioner
# 26364  26364      F   N       N          0      157500.0   Pensioner
# 26365  26365      M   Y       N          0      202500.0   Pensioner
# 26367  26367      F   N       Y          0      225000.0   Pensioner
# 26375  26375      F   Y       Y          0      157500.0   Pensioner
# 26376  26376      F   N       Y          0       90000.0   Pensioner
# 26378  26378      F   N       Y          0      180000.0   Pensioner
# 26380  26380      M   Y       Y          0      135000.0   Pensioner
# 26382  26382      F   N       Y          0      112500.0   Pensioner
# 26389  26389      F   N       Y          0      180000.0   Pensioner
# 26401  26401      F   Y       Y          0      225000.0   Pensioner
# 26402  26402      M   Y       N          0      292500.0   Pensioner
# 26406  26406      F   N       Y          0      144000.0   Pensioner
# 26427  26427      F   N       Y          0       67500.0   Pensioner
# 26431  26431      F   N       Y          0      225000.0   Pensioner
# 26432  26432      F   Y       Y          0       72000.0   Pensioner
# 26439  26439      F   N       Y          0       67500.0   Pensioner
# 26441  26441      F   N       Y          0       90000.0   Pensioner
# 26443  26443      F   N       Y          0       90000.0   Pensioner
#
#                             edu_type           family_type  \
# 14     Secondary / secondary special  Single / not married
# 18     Secondary / secondary special               Married
# 21     Secondary / secondary special               Married
# 24     Secondary / secondary special  Single / not married
# 46     Secondary / secondary special                 Widow
# 48     Secondary / secondary special               Married
# 52     Secondary / secondary special               Married
# 58     Secondary / secondary special               Married
# 59                  Higher education               Married
# 60     Secondary / secondary special             Separated
# 73     Secondary / secondary special               Married
# 84     Secondary / secondary special               Married
# 94     Secondary / secondary special               Married
# 95     Secondary / secondary special               Married
# 115    Secondary / secondary special               Married
# 120    Secondary / secondary special                 Widow
# 134    Secondary / secondary special                 Widow
# 138    Secondary / secondary special               Married
# 155    Secondary / secondary special               Married
# 159                 Higher education               Married
# 163    Secondary / secondary special               Married
# 166    Secondary / secondary special                 Widow
# 173    Secondary / secondary special               Married
# 178    Secondary / secondary special               Married
# 181    Secondary / secondary special               Married
# 183    Secondary / secondary special               Married
# 188    Secondary / secondary special                 Widow
# 190    Secondary / secondary special  Single / not married
# 191    Secondary / secondary special               Married
# 209    Secondary / secondary special               Married
# ...                              ...                   ...
# 26262  Secondary / secondary special  Single / not married
# 26263  Secondary / secondary special                 Widow
# 26266  Secondary / secondary special               Married
# 26279  Secondary / secondary special        Civil marriage
# 26283               Higher education                 Widow
# 26291  Secondary / secondary special               Married
# 26321  Secondary / secondary special               Married
# 26325  Secondary / secondary special               Married
# 26329  Secondary / secondary special  Single / not married
# 26334  Secondary / secondary special                 Widow
# 26341  Secondary / secondary special               Married
# 26361  Secondary / secondary special                 Widow
# 26364  Secondary / secondary special               Married
# 26365               Higher education               Married
# 26367  Secondary / secondary special        Civil marriage
# 26375  Secondary / secondary special                 Widow
# 26376               Higher education  Single / not married
# 26378  Secondary / secondary special               Married
# 26380  Secondary / secondary special               Married
# 26382  Secondary / secondary special  Single / not married
# 26389               Higher education               Married
# 26401  Secondary / secondary special               Married
# 26402  Secondary / secondary special               Married
# 26406  Secondary / secondary special               Married
# 26427  Secondary / secondary special                 Widow
# 26431  Secondary / secondary special                 Widow
# 26432  Secondary / secondary special               Married
# 26439  Secondary / secondary special               Married
# 26441              Incomplete higher             Separated
# 26443  Secondary / secondary special  Single / not married
#
#                 house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  \
# 14       House / apartment  ...         365243           1           0      1
# 18       House / apartment  ...         365243           1           0      0
# 21       House / apartment  ...         365243           1           0      1
# 24       House / apartment  ...         365243           1           0      1
# 46       House / apartment  ...         365243           1           0      1
# 48       House / apartment  ...         365243           1           0      0
# 52       House / apartment  ...         365243           1           0      1
# 58       House / apartment  ...         365243           1           0      0
# 59       House / apartment  ...         365243           1           0      1
# 60       House / apartment  ...         365243           1           0      0
# 73       House / apartment  ...         365243           1           0      1
# 84       House / apartment  ...         365243           1           0      1
# 94       House / apartment  ...         365243           1           0      0
# 95       House / apartment  ...         365243           1           0      1
# 115      House / apartment  ...         365243           1           0      0
# 120      House / apartment  ...         365243           1           0      0
# 134      House / apartment  ...         365243           1           0      0
# 138      House / apartment  ...         365243           1           0      0
# 155      House / apartment  ...         365243           1           0      0
# 159      House / apartment  ...         365243           1           0      1
# 163      House / apartment  ...         365243           1           0      0
# 166      House / apartment  ...         365243           1           0      1
# 173      House / apartment  ...         365243           1           0      0
# 178      House / apartment  ...         365243           1           0      0
# 181      House / apartment  ...         365243           1           0      0
# 183      House / apartment  ...         365243           1           0      1
# 188      House / apartment  ...         365243           1           0      0
# 190      House / apartment  ...         365243           1           0      1
# 191      House / apartment  ...         365243           1           0      0
# 209      House / apartment  ...         365243           1           0      1
# ...                    ...  ...            ...         ...         ...    ...
# 26262    House / apartment  ...         365243           1           0      0
# 26263    House / apartment  ...         365243           1           0      0
# 26266    House / apartment  ...         365243           1           0      0
# 26279    House / apartment  ...         365243           1           0      0
# 26283    House / apartment  ...         365243           1           0      0
# 26291    House / apartment  ...         365243           1           0      0
# 26321    House / apartment  ...         365243           1           0      0
# 26325    House / apartment  ...         365243           1           0      0
# 26329    House / apartment  ...         365243           1           0      0
# 26334    House / apartment  ...         365243           1           0      1
# 26341  Municipal apartment  ...         365243           1           0      1
# 26361    House / apartment  ...         365243           1           0      0
# 26364    House / apartment  ...         365243           1           0      0
# 26365    House / apartment  ...         365243           1           0      0
# 26367    House / apartment  ...         365243           1           0      0
# 26375    House / apartment  ...         365243           1           0      0
# 26376    House / apartment  ...         365243           1           0      0
# 26378    House / apartment  ...         365243           1           0      0
# 26380    House / apartment  ...         365243           1           0      0
# 26382    House / apartment  ...         365243           1           0      1
# 26389    House / apartment  ...         365243           1           0      0
# 26401    House / apartment  ...         365243           1           0      0
# 26402    House / apartment  ...         365243           1           0      0
# 26406    House / apartment  ...         365243           1           0      1
# 26427    House / apartment  ...         365243           1           0      0
# 26431    House / apartment  ...         365243           1           0      0
# 26432    House / apartment  ...         365243           1           0      1
# 26439    House / apartment  ...         365243           1           0      0
# 26441    House / apartment  ...         365243           1           0      0
# 26443    House / apartment  ...         365243           1           0      0
#
#        email  occyp_type family_size  begin_month  credit  employeed
# 14         0         NaN         1.0        -41.0     2.0          0
# 18         0         NaN         2.0        -37.0     2.0          0
# 21         0         NaN         2.0         -7.0     2.0          0
# 24         0         NaN         1.0         -5.0     2.0          0
# 46         0         NaN         1.0        -24.0     2.0          0
# 48         0         NaN         2.0         -4.0     2.0          0
# 52         0         NaN         2.0        -37.0     2.0          0
# 58         0         NaN         2.0        -23.0     2.0          0
# 59         0         NaN         2.0        -25.0     2.0          0
# 60         0         NaN         1.0         -1.0     1.0          0
# 73         0         NaN         2.0        -34.0     2.0          0
# 84         0         NaN         2.0        -27.0     2.0          0
# 94         0         NaN         2.0        -26.0     2.0          0
# 95         0         NaN         2.0        -14.0     2.0          0
# 115        0         NaN         2.0        -49.0     2.0          0
# 120        0         NaN         1.0         -4.0     1.0          0
# 134        0         NaN         1.0         -6.0     2.0          0
# 138        0         NaN         2.0         -2.0     0.0          0
# 155        0         NaN         2.0        -35.0     2.0          0
# 159        0         NaN         2.0        -51.0     1.0          0
# 163        0         NaN         2.0        -24.0     2.0          0
# 166        0         NaN         1.0        -15.0     2.0          0
# 173        0         NaN         2.0        -19.0     0.0          0
# 178        0         NaN         2.0        -12.0     2.0          0
# 181        0         NaN         2.0         -5.0     0.0          0
# 183        0         NaN         2.0        -42.0     1.0          0
# 188        0         NaN         1.0        -26.0     0.0          0
# 190        0         NaN         1.0        -13.0     0.0          0
# 191        0         NaN         2.0        -28.0     2.0          0
# 209        0         NaN         2.0        -18.0     2.0          0
# ...      ...         ...         ...          ...     ...        ...
# 26262      0         NaN         1.0        -43.0     2.0          0
# 26263      0         NaN         1.0         -9.0     2.0          0
# 26266      0         NaN         2.0         -6.0     1.0          0
# 26279      0         NaN         2.0         -8.0     2.0          0
# 26283      0         NaN         1.0        -36.0     2.0          0
# 26291      0         NaN         2.0        -39.0     2.0          0
# 26321      0         NaN         2.0        -14.0     2.0          0
# 26325      0         NaN         2.0        -44.0     2.0          0
# 26329      0         NaN         1.0         -3.0     0.0          0
# 26334      0         NaN         1.0        -16.0     2.0          0
# 26341      0         NaN         2.0        -17.0     2.0          0
# 26361      0         NaN         1.0        -10.0     2.0          0
# 26364      1         NaN         2.0        -43.0     2.0          0
# 26365      0         NaN         2.0        -44.0     1.0          0
# 26367      0         NaN         2.0        -50.0     2.0          0
# 26375      0         NaN         1.0        -29.0     2.0          0
# 26376      0         NaN         1.0        -22.0     2.0          0
# 26378      0         NaN         2.0        -46.0     2.0          0
# 26380      0         NaN         2.0        -19.0     2.0          0
# 26382      1         NaN         1.0         -5.0     1.0          0
# 26389      0         NaN         2.0        -40.0     2.0          0
# 26401      0         NaN         2.0        -41.0     1.0          0
# 26402      0         NaN         2.0        -51.0     2.0          0
# 26406      0         NaN         2.0         -3.0     1.0          0
# 26427      0         NaN         1.0        -54.0     2.0          0
# 26431      1         NaN         1.0        -60.0     1.0          0
# 26432      0         NaN         2.0        -17.0     1.0          0
# 26439      0         NaN         2.0        -57.0     2.0          0
# 26441      0         NaN         1.0        -43.0     2.0          0
# 26443      0         NaN         1.0        -21.0     1.0          0
#
# [4438 rows x 21 columns]

# %%
non_occyp.loc[(non_occyp['employeed']==0),'occyp_type']='inocc'
#고용되지 않은 사람은 inocc로 처리.

# %%
non_occyp.loc[(non_occyp['employeed']==0),'DAYS_EMPLOYED']=0

# %%
non_occyp['income_type'].value_counts().plot(kind='bar')
#결측치가 들어간 데이터 내 소득 분류는 연금을 받은 사람들이 많다.

# %%
occyp['income_type'].value_counts().plot(kind='bar')
#역시 연금을 받은 사람이 많다.

# %%
non_occyp.loc[non_occyp['income_type']=='Pensioner']
#연금을 받는 사람들 대상으로 조사 결과 income_total은 결측치가 없다
# Out:
#        index gender car reality  child_num  income_total income_type  \
# 14        14      F   N       Y          0      157500.0   Pensioner
# 18        18      F   N       Y          0      216000.0   Pensioner
# 21        21      F   N       N          0      157500.0   Pensioner
# 24        24      F   N       N          0      202500.0   Pensioner
# 46        46      F   N       N          0      135000.0   Pensioner
# 48        48      F   N       Y          0       99000.0   Pensioner
# 52        52      F   N       Y          0       54000.0   Pensioner
# 58        58      F   N       Y          0      144000.0   Pensioner
# 59        59      F   N       Y          0      360000.0   Pensioner
# 60        60      M   Y       Y          0      112500.0   Pensioner
# 73        73      F   N       Y          0      180000.0   Pensioner
# 84        84      M   Y       Y          0      135000.0   Pensioner
# 94        94      F   N       Y          0      180000.0   Pensioner
# 95        95      M   N       Y          0       79650.0   Pensioner
# 115      115      F   N       N          0       81000.0   Pensioner
# 120      120      F   N       Y          0      157500.0   Pensioner
# 134      134      F   Y       Y          0      135000.0   Pensioner
# 138      138      F   N       Y          0       54000.0   Pensioner
# 155      155      F   N       Y          0       90000.0   Pensioner
# 159      159      F   N       Y          0      153000.0   Pensioner
# 163      163      F   N       Y          0      155250.0   Pensioner
# 166      166      F   N       Y          0      495000.0   Pensioner
# 173      173      F   N       Y          0      189000.0   Pensioner
# 178      178      M   N       N          0      126000.0   Pensioner
# 181      181      F   N       Y          0       90000.0   Pensioner
# 183      183      F   N       Y          0      157500.0   Pensioner
# 188      188      F   N       N          0      112500.0   Pensioner
# 190      190      F   N       Y          0       90000.0   Pensioner
# 191      191      F   N       N          0      121500.0   Pensioner
# 209      209      F   N       Y          0       81000.0   Pensioner
# ...      ...    ...  ..     ...        ...           ...         ...
# 26262  26262      F   N       Y          0      184500.0   Pensioner
# 26263  26263      F   N       Y          0      180000.0   Pensioner
# 26266  26266      F   Y       Y          0      270000.0   Pensioner
# 26279  26279      F   N       Y          0       81000.0   Pensioner
# 26283  26283      F   Y       N          0       90000.0   Pensioner
# 26291  26291      F   N       Y          0      180000.0   Pensioner
# 26321  26321      F   N       Y          0       94500.0   Pensioner
# 26325  26325      F   N       Y          0       67500.0   Pensioner
# 26329  26329      F   N       Y          0      225000.0   Pensioner
# 26334  26334      F   N       Y          0      112500.0   Pensioner
# 26341  26341      F   N       Y          0       47250.0   Pensioner
# 26361  26361      F   N       Y          0      202500.0   Pensioner
# 26364  26364      F   N       N          0      157500.0   Pensioner
# 26365  26365      M   Y       N          0      202500.0   Pensioner
# 26367  26367      F   N       Y          0      225000.0   Pensioner
# 26375  26375      F   Y       Y          0      157500.0   Pensioner
# 26376  26376      F   N       Y          0       90000.0   Pensioner
# 26378  26378      F   N       Y          0      180000.0   Pensioner
# 26380  26380      M   Y       Y          0      135000.0   Pensioner
# 26382  26382      F   N       Y          0      112500.0   Pensioner
# 26389  26389      F   N       Y          0      180000.0   Pensioner
# 26401  26401      F   Y       Y          0      225000.0   Pensioner
# 26402  26402      M   Y       N          0      292500.0   Pensioner
# 26406  26406      F   N       Y          0      144000.0   Pensioner
# 26427  26427      F   N       Y          0       67500.0   Pensioner
# 26431  26431      F   N       Y          0      225000.0   Pensioner
# 26432  26432      F   Y       Y          0       72000.0   Pensioner
# 26439  26439      F   N       Y          0       67500.0   Pensioner
# 26441  26441      F   N       Y          0       90000.0   Pensioner
# 26443  26443      F   N       Y          0       90000.0   Pensioner
#
#                             edu_type           family_type  \
# 14     Secondary / secondary special  Single / not married
# 18     Secondary / secondary special               Married
# 21     Secondary / secondary special               Married
# 24     Secondary / secondary special  Single / not married
# 46     Secondary / secondary special                 Widow
# 48     Secondary / secondary special               Married
# 52     Secondary / secondary special               Married
# 58     Secondary / secondary special               Married
# 59                  Higher education               Married
# 60     Secondary / secondary special             Separated
# 73     Secondary / secondary special               Married
# 84     Secondary / secondary special               Married
# 94     Secondary / secondary special               Married
# 95     Secondary / secondary special               Married
# 115    Secondary / secondary special               Married
# 120    Secondary / secondary special                 Widow
# 134    Secondary / secondary special                 Widow
# 138    Secondary / secondary special               Married
# 155    Secondary / secondary special               Married
# 159                 Higher education               Married
# 163    Secondary / secondary special               Married
# 166    Secondary / secondary special                 Widow
# 173    Secondary / secondary special               Married
# 178    Secondary / secondary special               Married
# 181    Secondary / secondary special               Married
# 183    Secondary / secondary special               Married
# 188    Secondary / secondary special                 Widow
# 190    Secondary / secondary special  Single / not married
# 191    Secondary / secondary special               Married
# 209    Secondary / secondary special               Married
# ...                              ...                   ...
# 26262  Secondary / secondary special  Single / not married
# 26263  Secondary / secondary special                 Widow
# 26266  Secondary / secondary special               Married
# 26279  Secondary / secondary special        Civil marriage
# 26283               Higher education                 Widow
# 26291  Secondary / secondary special               Married
# 26321  Secondary / secondary special               Married
# 26325  Secondary / secondary special               Married
# 26329  Secondary / secondary special  Single / not married
# 26334  Secondary / secondary special                 Widow
# 26341  Secondary / secondary special               Married
# 26361  Secondary / secondary special                 Widow
# 26364  Secondary / secondary special               Married
# 26365               Higher education               Married
# 26367  Secondary / secondary special        Civil marriage
# 26375  Secondary / secondary special                 Widow
# 26376               Higher education  Single / not married
# 26378  Secondary / secondary special               Married
# 26380  Secondary / secondary special               Married
# 26382  Secondary / secondary special  Single / not married
# 26389               Higher education               Married
# 26401  Secondary / secondary special               Married
# 26402  Secondary / secondary special               Married
# 26406  Secondary / secondary special               Married
# 26427  Secondary / secondary special                 Widow
# 26431  Secondary / secondary special                 Widow
# 26432  Secondary / secondary special               Married
# 26439  Secondary / secondary special               Married
# 26441              Incomplete higher             Separated
# 26443  Secondary / secondary special  Single / not married
#
#                 house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  \
# 14       House / apartment  ...              0           1           0      1
# 18       House / apartment  ...              0           1           0      0
# 21       House / apartment  ...              0           1           0      1
# 24       House / apartment  ...              0           1           0      1
# 46       House / apartment  ...              0           1           0      1
# 48       House / apartment  ...              0           1           0      0
# 52       House / apartment  ...              0           1           0      1
# 58       House / apartment  ...              0           1           0      0
# 59       House / apartment  ...              0           1           0      1
# 60       House / apartment  ...              0           1           0      0
# 73       House / apartment  ...              0           1           0      1
# 84       House / apartment  ...              0           1           0      1
# 94       House / apartment  ...              0           1           0      0
# 95       House / apartment  ...              0           1           0      1
# 115      House / apartment  ...              0           1           0      0
# 120      House / apartment  ...              0           1           0      0
# 134      House / apartment  ...              0           1           0      0
# 138      House / apartment  ...              0           1           0      0
# 155      House / apartment  ...              0           1           0      0
# 159      House / apartment  ...              0           1           0      1
# 163      House / apartment  ...              0           1           0      0
# 166      House / apartment  ...              0           1           0      1
# 173      House / apartment  ...              0           1           0      0
# 178      House / apartment  ...              0           1           0      0
# 181      House / apartment  ...              0           1           0      0
# 183      House / apartment  ...              0           1           0      1
# 188      House / apartment  ...              0           1           0      0
# 190      House / apartment  ...              0           1           0      1
# 191      House / apartment  ...              0           1           0      0
# 209      House / apartment  ...              0           1           0      1
# ...                    ...  ...            ...         ...         ...    ...
# 26262    House / apartment  ...              0           1           0      0
# 26263    House / apartment  ...              0           1           0      0
# 26266    House / apartment  ...              0           1           0      0
# 26279    House / apartment  ...              0           1           0      0
# 26283    House / apartment  ...              0           1           0      0
# 26291    House / apartment  ...              0           1           0      0
# 26321    House / apartment  ...              0           1           0      0
# 26325    House / apartment  ...              0           1           0      0
# 26329    House / apartment  ...              0           1           0      0
# 26334    House / apartment  ...              0           1           0      1
# 26341  Municipal apartment  ...              0           1           0      1
# 26361    House / apartment  ...              0           1           0      0
# 26364    House / apartment  ...              0           1           0      0
# 26365    House / apartment  ...              0           1           0      0
# 26367    House / apartment  ...              0           1           0      0
# 26375    House / apartment  ...              0           1           0      0
# 26376    House / apartment  ...              0           1           0      0
# 26378    House / apartment  ...              0           1           0      0
# 26380    House / apartment  ...              0           1           0      0
# 26382    House / apartment  ...              0           1           0      1
# 26389    House / apartment  ...              0           1           0      0
# 26401    House / apartment  ...              0           1           0      0
# 26402    House / apartment  ...              0           1           0      0
# 26406    House / apartment  ...              0           1           0      1
# 26427    House / apartment  ...              0           1           0      0
# 26431    House / apartment  ...              0           1           0      0
# 26432    House / apartment  ...              0           1           0      1
# 26439    House / apartment  ...              0           1           0      0
# 26441    House / apartment  ...              0           1           0      0
# 26443    House / apartment  ...              0           1           0      0
#
#        email  occyp_type family_size  begin_month  credit  employeed
# 14         0       inocc         1.0        -41.0     2.0          0
# 18         0       inocc         2.0        -37.0     2.0          0
# 21         0       inocc         2.0         -7.0     2.0          0
# 24         0       inocc         1.0         -5.0     2.0          0
# 46         0       inocc         1.0        -24.0     2.0          0
# 48         0       inocc         2.0         -4.0     2.0          0
# 52         0       inocc         2.0        -37.0     2.0          0
# 58         0       inocc         2.0        -23.0     2.0          0
# 59         0       inocc         2.0        -25.0     2.0          0
# 60         0       inocc         1.0         -1.0     1.0          0
# 73         0       inocc         2.0        -34.0     2.0          0
# 84         0       inocc         2.0        -27.0     2.0          0
# 94         0       inocc         2.0        -26.0     2.0          0
# 95         0       inocc         2.0        -14.0     2.0          0
# 115        0       inocc         2.0        -49.0     2.0          0
# 120        0       inocc         1.0         -4.0     1.0          0
# 134        0       inocc         1.0         -6.0     2.0          0
# 138        0       inocc         2.0         -2.0     0.0          0
# 155        0       inocc         2.0        -35.0     2.0          0
# 159        0       inocc         2.0        -51.0     1.0          0
# 163        0       inocc         2.0        -24.0     2.0          0
# 166        0       inocc         1.0        -15.0     2.0          0
# 173        0       inocc         2.0        -19.0     0.0          0
# 178        0       inocc         2.0        -12.0     2.0          0
# 181        0       inocc         2.0         -5.0     0.0          0
# 183        0       inocc         2.0        -42.0     1.0          0
# 188        0       inocc         1.0        -26.0     0.0          0
# 190        0       inocc         1.0        -13.0     0.0          0
# 191        0       inocc         2.0        -28.0     2.0          0
# 209        0       inocc         2.0        -18.0     2.0          0
# ...      ...         ...         ...          ...     ...        ...
# 26262      0       inocc         1.0        -43.0     2.0          0
# 26263      0       inocc         1.0         -9.0     2.0          0
# 26266      0       inocc         2.0         -6.0     1.0          0
# 26279      0       inocc         2.0         -8.0     2.0          0
# 26283      0       inocc         1.0        -36.0     2.0          0
# 26291      0       inocc         2.0        -39.0     2.0          0
# 26321      0       inocc         2.0        -14.0     2.0          0
# 26325      0       inocc         2.0        -44.0     2.0          0
# 26329      0       inocc         1.0         -3.0     0.0          0
# 26334      0       inocc         1.0        -16.0     2.0          0
# 26341      0       inocc         2.0        -17.0     2.0          0
# 26361      0       inocc         1.0        -10.0     2.0          0
# 26364      1       inocc         2.0        -43.0     2.0          0
# 26365      0       inocc         2.0        -44.0     1.0          0
# 26367      0       inocc         2.0        -50.0     2.0          0
# 26375      0       inocc         1.0        -29.0     2.0          0
# 26376      0       inocc         1.0        -22.0     2.0          0
# 26378      0       inocc         2.0        -46.0     2.0          0
# 26380      0       inocc         2.0        -19.0     2.0          0
# 26382      1       inocc         1.0         -5.0     1.0          0
# 26389      0       inocc         2.0        -40.0     2.0          0
# 26401      0       inocc         2.0        -41.0     1.0          0
# 26402      0       inocc         2.0        -51.0     2.0          0
# 26406      0       inocc         2.0         -3.0     1.0          0
# 26427      0       inocc         1.0        -54.0     2.0          0
# 26431      1       inocc         1.0        -60.0     1.0          0
# 26432      0       inocc         2.0        -17.0     1.0          0
# 26439      0       inocc         2.0        -57.0     2.0          0
# 26441      0       inocc         1.0        -43.0     2.0          0
# 26443      0       inocc         1.0        -21.0     1.0          0
#
# [4440 rows x 21 columns]

# %%
non_occyp.isnull().sum() #3733개 남음
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       3733
# family_size         0
# begin_month         0
# credit              0
# employeed           0
# dtype: int64

# %%
non_occyp.head()
# Out:
#     index gender car reality  child_num  income_total           income_type  \
# 0       0      F   N       N          0      202500.0  Commercial associate
# 8       8      M   Y       Y          1      180000.0  Commercial associate
# 14     14      F   N       Y          0      157500.0             Pensioner
# 18     18      F   N       Y          0      216000.0             Pensioner
# 19     19      F   N       Y          0      180000.0               Working
#
#                          edu_type           family_type           house_type  \
# 0                Higher education               Married  Municipal apartment
# 8                Higher education               Married    House / apartment
# 14  Secondary / secondary special  Single / not married    House / apartment
# 18  Secondary / secondary special               Married    House / apartment
# 19  Secondary / secondary special               Married    House / apartment
#
#     ...  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  occyp_type  \
# 0   ...          -4709           1           0      0      0         NaN
# 8   ...          -1466           1           0      0      1         NaN
# 14  ...              0           1           0      1      0       inocc
# 18  ...              0           1           0      0      0       inocc
# 19  ...          -6031           1           0      0      0         NaN
#
#    family_size  begin_month  credit  employeed
# 0          2.0         -6.0     1.0          1
# 8          3.0        -38.0     2.0          1
# 14         1.0        -41.0     2.0          0
# 18         2.0        -37.0     2.0          0
# 19         2.0         -7.0     2.0          1
#
# [5 rows x 21 columns]

# %%
occyp.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
# 5      5      F   N       Y          2      270000.0               Working
#
#                         edu_type     family_type         house_type  ...  \
# 1  Secondary / secondary special  Civil marriage  House / apartment  ...
# 2               Higher education         Married  House / apartment  ...
# 3  Secondary / secondary special         Married  House / apartment  ...
# 4               Higher education         Married  House / apartment  ...
# 5  Secondary / secondary special         Married  House / apartment  ...
#
#    DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email             occyp_type  \
# 1          -1540           1           0      0      1               Laborers
# 2          -4434           1           0      1      0               Managers
# 3          -2092           1           0      1      0            Sales staff
# 4          -2105           1           0      0      0               Managers
# 5          -4996           1           0      0      1  High skill tech staff
#
#   family_size  begin_month  credit  employeed
# 1         3.0         -5.0     1.0          1
# 2         2.0        -22.0     2.0          1
# 3         2.0        -37.0     0.0          1
# 4         2.0        -26.0     2.0          1
# 5         4.0        -18.0     1.0          1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### regression

# %%
data=pd.concat([occyp,non_occyp])

# %%
data.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
# 5      5      F   N       Y          2      270000.0               Working
#
#                         edu_type     family_type         house_type  ...  \
# 1  Secondary / secondary special  Civil marriage  House / apartment  ...
# 2               Higher education         Married  House / apartment  ...
# 3  Secondary / secondary special         Married  House / apartment  ...
# 4               Higher education         Married  House / apartment  ...
# 5  Secondary / secondary special         Married  House / apartment  ...
#
#    DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email             occyp_type  \
# 1          -1540           1           0      0      1               Laborers
# 2          -4434           1           0      1      0               Managers
# 3          -2092           1           0      1      0            Sales staff
# 4          -2105           1           0      0      0               Managers
# 5          -4996           1           0      0      1  High skill tech staff
#
#   family_size  begin_month  credit  employeed
# 1         3.0         -5.0     1.0          1
# 2         2.0        -22.0     2.0          1
# 3         2.0        -37.0     0.0          1
# 4         2.0        -26.0     2.0          1
# 5         4.0        -18.0     1.0          1
#
# [5 rows x 21 columns]

# %%
#명목형 변수 라벨화
label_encoder=preprocessing.LabelEncoder()
data['gender'] = data['gender'].replace(['F','M'],[0,1])
data['car'] = data['car'].replace(['N','Y'],[0,1])
data['reality'] = data['reality'].replace(['N','Y'],[0,1])
data['income_type']=label_encoder.fit_transform(data['income_type'])
#################################################################
data['edu_type']=label_encoder.fit_transform(data['edu_type'])
########################################################################
data['family_type']=label_encoder.fit_transform(data['family_type'])
########################################################################
data['house_type']=label_encoder.fit_transform(data['house_type'])
########################################################################

# %%
data.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
# 5      5       0    0        1          2      270000.0            4
#
#    edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 1         4            0           1  ...          -1540           1
# 2         1            1           1  ...          -4434           1
# 3         4            1           1  ...          -2092           1
# 4         1            1           1  ...          -2105           1
# 5         4            1           1  ...          -4996           1
#
#    work_phone  phone  email             occyp_type family_size  begin_month  \
# 1           0      0      1               Laborers         3.0         -5.0
# 2           0      1      0               Managers         2.0        -22.0
# 3           0      1      0            Sales staff         2.0        -37.0
# 4           0      0      0               Managers         2.0        -26.0
# 5           0      0      1  High skill tech staff         4.0        -18.0
#
#    credit  employeed
# 1     1.0          1
# 2     2.0          1
# 3     0.0          1
# 4     2.0          1
# 5     1.0          1
#
# [5 rows x 21 columns]

# %%
null_data=data.loc[data['occyp_type'].isnull()]

# %%
null_data.head()#inocc 대체 후 결측치가 있는 것들
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 0       0       0    0        0          0      202500.0            0
# 8       8       1    1        1          1      180000.0            0
# 19     19       0    0        1          0      180000.0            4
# 20     20       1    0        0          0      180000.0            4
# 23     23       1    1        0          0      225000.0            4
#
#     edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0          1            1           2  ...          -4709           1
# 8          1            1           1  ...          -1466           1
# 19         4            1           1  ...          -6031           1
# 20         4            1           1  ...          -1753           1
# 23         4            1           2  ...           -444           1
#
#     work_phone  phone  email  occyp_type family_size  begin_month  credit  \
# 0            0      0      0         NaN         2.0         -6.0     1.0
# 8            0      0      1         NaN         3.0        -38.0     2.0
# 19           0      0      0         NaN         2.0         -7.0     2.0
# 20           0      1      0         NaN         2.0        -35.0     2.0
# 23           1      1      1         NaN         2.0        -18.0     2.0
#
#     employeed
# 0           1
# 8           1
# 19          1
# 20          1
# 23          1
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (26457, 21)

# %%
fill_data=data.dropna() #결측치 제거한 데이터

# %%
print(fill_data.shape,null_data.shape)
# Out:
# (22724, 21) (3733, 21)

# %%
fill_data['occyp_type_l']=label_encoder.fit_transform(fill_data['occyp_type'])
#결측치 없는 데이터 중 occyp_type를 라벨링한 변수를 추가(라벨링과 원래값 비교를 위해)

# %%
fill_data.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
# 5      5       0    0        1          2      270000.0            4
#
#    edu_type  family_type  house_type  ...  FLAG_MOBIL  work_phone  phone  \
# 1         4            0           1  ...           1           0      0
# 2         1            1           1  ...           1           0      1
# 3         4            1           1  ...           1           0      1
# 4         1            1           1  ...           1           0      0
# 5         4            1           1  ...           1           0      0
#
#    email             occyp_type  family_size begin_month  credit  employeed  \
# 1      1               Laborers          3.0        -5.0     1.0          1
# 2      0               Managers          2.0       -22.0     2.0          1
# 3      0            Sales staff          2.0       -37.0     0.0          1
# 4      0               Managers          2.0       -26.0     2.0          1
# 5      1  High skill tech staff          4.0       -18.0     1.0          1
#
#    occyp_type_l
# 1             8
# 2            10
# 3            14
# 4            10
# 5             6
#
# [5 rows x 22 columns]

# %%
fill_data.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month', 'credit', 'employeed',
#        'occyp_type_l'],
#       dtype='object')

# %%
null_data.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month', 'credit', 'employeed'],
#       dtype='object')

# %%
lin_reg = linear_model.LinearRegression()
x=fill_data[fill_data.columns.drop(['index','occyp_type','credit',
                                   'employeed','occyp_type_l'])]
#employeed(0,1)을 넣지 않고 days_employed에서 양수값을 0으로 처리한 상태에서 재시도
#라벨링한 occyp_type_l는 종속변수로 사용
y=fill_data['occyp_type_l']#라벨링 상태
lin_reg_model = lin_reg.fit(x, y)

# %%
x.shape
# Out:
# (22724, 17)

# %%
x_test=null_data[null_data.columns.drop(['index','occyp_type','credit','employeed'])]
y_test=null_data['occyp_type']
y_test=lin_reg.predict(x_test)#결측치가 있는 데이터에 대입

# %%
null_data['occyp_type']=y_test

# %%
null_data.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 0       0       0    0        0          0      202500.0            0
# 8       8       1    1        1          1      180000.0            0
# 19     19       0    0        1          0      180000.0            4
# 20     20       1    0        0          0      180000.0            4
# 23     23       1    1        0          0      225000.0            4
#
#     edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0          1            1           2  ...          -4709           1
# 8          1            1           1  ...          -1466           1
# 19         4            1           1  ...          -6031           1
# 20         4            1           1  ...          -1753           1
# 23         4            1           2  ...           -444           1
#
#     work_phone  phone  email  occyp_type  family_size  begin_month  credit  \
# 0            0      0      0    7.789922          2.0         -6.0     1.0
# 8            0      0      1    8.832769          3.0        -38.0     2.0
# 19           0      0      0    6.110326          2.0         -7.0     2.0
# 20           0      1      0   11.776212          2.0        -35.0     2.0
# 23           1      1      1    7.800152          2.0        -18.0     2.0
#
#     employeed
# 0           1
# 8           1
# 19          1
# 20          1
# 23          1
#
# [5 rows x 21 columns]

# %%
null_data.shape
# Out:
# (3733, 21)

# %%
null_data['occyp_type'].value_counts()
# Out:
# 6.700081     4
# 5.421080     4
# 9.070744     3
# 8.439904     3
# 7.718376     3
# 11.402574    3
# 10.948696    3
# 10.239545    3
# 5.566249     3
# 5.806243     3
# 9.708101     3
# 5.562085     3
# 11.094643    3
# 9.737606     3
# 11.195717    3
# 3.110578     3
# 6.793299     3
# 6.259562     3
# 10.643064    3
# 12.333151    3
# 6.411830     3
# 5.677078     3
# 5.667152     3
# 6.600869     3
# 7.514427     3
# 6.386043     3
# 7.195056     3
# 3.093324     3
# 8.151593     3
# 8.115841     2
#             ..
# 6.234998     1
# 6.637751     1
# 8.903048     1
# 6.076978     1
# 10.443665    1
# 5.650953     1
# 7.301871     1
# 7.536923     1
# 12.083631    1
# 9.109007     1
# 8.114869     1
# 5.543142     1
# 8.893868     1
# 12.290502    1
# 8.382629     1
# 5.089767     1
# 5.819519     1
# 13.502996    1
# 5.379099     1
# 5.553197     1
# 9.942124     1
# 8.211799     1
# 5.237153     1
# 8.557176     1
# 5.908814     1
# 3.896433     1
# 8.978194     1
# 5.254968     1
# 7.556375     1
# 6.156196     1
# Name: occyp_type, Length: 3357, dtype: int64

# %%
print(y[:10])
# Out:
# 1      8
# 2     10
# 3     14
# 4     10
# 5      6
# 6      3
# 7      4
# 9     11
# 10     8
# 11    10
# Name: occyp_type_l, dtype: int32

# %%
fill_data['occyp_type'].value_counts()
# Out:
# Laborers                 4512
# inocc                    4438
# Core staff               2646
# Sales staff              2539
# Managers                 2167
# Drivers                  1575
# High skill tech staff    1040
# Accountants               902
# Medicine staff            864
# Cooking staff             457
# Security staff            424
# Cleaning staff            403
# Private service staff     243
# Low-skill Laborers        127
# Waiters/barmen staff      124
# Secretaries                97
# Realty agents              63
# HR staff                   62
# IT staff                   41
# Name: occyp_type, dtype: int64

# %%
#fill_data['occyp_type_enc']=y_encoded
fill_data['occyp_type_l'].value_counts()
# Out:
# 8     4512
# 18    4438
# 3     2646
# 14    2539
# 10    2167
# 4     1575
# 6     1040
# 0      902
# 11     864
# 2      457
# 16     424
# 1      403
# 12     243
# 9      127
# 17     124
# 15      97
# 13      63
# 5       62
# 7       41
# Name: occyp_type_l, dtype: int64

# %%
fill_data['occyp_type_l'].unique()#라벨링값
# Out:
# array([ 8, 10, 14,  6,  3,  4, 11,  0, 13, 16,  1, 12,  2, 15,  5,  7,  9,
#        17, 18], dtype=int64)

# %%
fill_data['occyp_type'].unique()#라벨링값 순서대로 8:Laborers,10:Managers,...
# Out:
# array(['Laborers', 'Managers', 'Sales staff', 'High skill tech staff',
#        'Core staff', 'Drivers', 'Medicine staff', 'Accountants',
#        'Realty agents', 'Security staff', 'Cleaning staff',
#        'Private service staff', 'Cooking staff', 'Secretaries',
#        'HR staff', 'IT staff', 'Low-skill Laborers',
#        'Waiters/barmen staff', 'inocc'], dtype=object)

# %%
np.round(y_test,0)
# Out:
# array([8., 9., 6., ..., 7., 7., 8.])

# %%
null_data['occyp_type']=np.round(null_data['occyp_type'],0)#반올림

# %%
null_data['occyp_type'].describe()
# Out:
# count    3733.000000
# mean        8.293598
# std         2.371466
# min         2.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        16.000000
# Name: occyp_type, dtype: float64

# %%
null_data['occyp_type'].value_counts()
# Out:
# 8.0     602
# 6.0     552
# 9.0     542
# 7.0     525
# 10.0    400
# 11.0    391
# 5.0     257
# 12.0    158
# 4.0      99
# 13.0     83
# 14.0     59
# 3.0      38
# 15.0     22
# 16.0      3
# 2.0       2
# Name: occyp_type, dtype: int64

# %%
#라벨링->원래값
null_data.loc[null_data['occyp_type']==2.0,'occyp_type']= 'Cooking staff'
null_data.loc[null_data['occyp_type']==3.0,'occyp_type']='Core staff'
null_data.loc[null_data['occyp_type']==4.0,'occyp_type']='Drivers'
null_data.loc[null_data['occyp_type']==5.0,'occyp_type']='HR staff'
null_data.loc[null_data['occyp_type']==6.0,'occyp_type']='High skill tech staff'
null_data.loc[null_data['occyp_type']==7.0,'occyp_type']='IT staff'
null_data.loc[null_data['occyp_type']==8.0,'occyp_type']='Laborers'
null_data.loc[null_data['occyp_type']==9.0,'occyp_type']='Low-skill Laborers'
null_data.loc[null_data['occyp_type']==10.0,'occyp_type']='Managers'
null_data.loc[null_data['occyp_type']==11.0,'occyp_type']='Medicine staff'
null_data.loc[null_data['occyp_type']==12.0,'occyp_type']='Private service staff'
null_data.loc[null_data['occyp_type']==13.0,'occyp_type']='Realty agents'
null_data.loc[null_data['occyp_type']==14.0,'occyp_type']='Sales staff'
null_data.loc[null_data['occyp_type']==15.0,'occyp_type']='Secretaries'

# %%
null_data.loc[null_data['occyp_type']==16.0,'occyp_type']='Security staff'

# %%
fill_data['occyp_type'].value_counts().plot(kind='bar')

# %%
null_data['occyp_type'].value_counts().plot(kind='bar')

# %%
null_data.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month', 'credit', 'employeed'],
#       dtype='object')

# %%
fill_data.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month', 'credit', 'employeed',
#        'occyp_type_l'],
#       dtype='object')

# %%
fill_data=fill_data.drop('occyp_type_l',axis=1)

# %%
df=pd.concat([null_data,fill_data]).sort_values(by='index')
df.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0      0       0    0        0          0      202500.0            0
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
#
#    edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         1            1           2  ...          -4709           1
# 1         4            0           1  ...          -1540           1
# 2         1            1           1  ...          -4434           1
# 3         4            1           1  ...          -2092           1
# 4         1            1           1  ...          -2105           1
#
#    work_phone  phone  email   occyp_type family_size  begin_month  credit  \
# 0           0      0      0     Laborers         2.0         -6.0     1.0
# 1           0      0      1     Laborers         3.0         -5.0     1.0
# 2           0      1      0     Managers         2.0        -22.0     2.0
# 3           0      1      0  Sales staff         2.0        -37.0     0.0
# 4           0      0      0     Managers         2.0        -26.0     2.0
#
#    employeed
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 21 columns]

# %%
null_data.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 0       0       0    0        0          0      202500.0            0
# 8       8       1    1        1          1      180000.0            0
# 19     19       0    0        1          0      180000.0            4
# 20     20       1    0        0          0      180000.0            4
# 23     23       1    1        0          0      225000.0            4
#
#     edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0          1            1           2  ...          -4709           1
# 8          1            1           1  ...          -1466           1
# 19         4            1           1  ...          -6031           1
# 20         4            1           1  ...          -1753           1
# 23         4            1           2  ...           -444           1
#
#     work_phone  phone  email             occyp_type family_size  begin_month  \
# 0            0      0      0               Laborers         2.0         -6.0
# 8            0      0      1     Low-skill Laborers         3.0        -38.0
# 19           0      0      0  High skill tech staff         2.0         -7.0
# 20           0      1      0  Private service staff         2.0        -35.0
# 23           1      1      1               Laborers         2.0        -18.0
#
#     credit  employeed
# 0      1.0          1
# 8      2.0          1
# 19     2.0          1
# 20     2.0          1
# 23     2.0          1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### test파일 전처리

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# index            10000 non-null int64
# gender           10000 non-null object
# car              10000 non-null object
# reality          10000 non-null object
# child_num        10000 non-null int64
# income_total     10000 non-null float64
# income_type      10000 non-null object
# edu_type         10000 non-null object
# family_type      10000 non-null object
# house_type       10000 non-null object
# DAYS_BIRTH       10000 non-null int64
# DAYS_EMPLOYED    10000 non-null int64
# FLAG_MOBIL       10000 non-null int64
# work_phone       10000 non-null int64
# phone            10000 non-null int64
# email            10000 non-null int64
# occyp_type       6848 non-null object
# family_size      10000 non-null float64
# begin_month      10000 non-null float64
# dtypes: float64(3), int64(8), object(8)
# memory usage: 1.4+ MB

# %%
df_test.isnull().sum() #결측치 3152
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       3152
# family_size         0
# begin_month         0
# dtype: int64

# %%
df_test['occyp_type'].value_counts().plot(kind='bar')
#laborers가 많은 편. sales staff,core staff,managers,drivers 순으로 나타남
#노동자들이 많은 타입

# %%
df_test['occyp_type'].value_counts()
# Out:
# Laborers                 1699
# Sales staff               946
# Core staff                945
# Managers                  845
# Drivers                   563
# High skill tech staff     343
# Medicine staff            343
# Accountants               339
# Cooking staff             198
# Security staff            168
# Cleaning staff            148
# Private service staff     101
# Secretaries                54
# Waiters/barmen staff       50
# Low-skill Laborers         48
# HR staff                   23
# IT staff                   19
# Realty agents              16
# Name: occyp_type, dtype: int64

# %%
df_test.loc[df_test['DAYS_EMPLOYED']>0,'DAYS_EMPLOYED']=0

# %%
df_non_occyp=df_test.loc[df_test['occyp_type'].isnull()]#직업유형이 없는 사람
df_occyp=df_test.dropna()#직업유형이 있는 사람(결측치 제거)

# %%
df_non_occyp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3152 entries, 0 to 9998
# Data columns (total 19 columns):
# index            3152 non-null int64
# gender           3152 non-null object
# car              3152 non-null object
# reality          3152 non-null object
# child_num        3152 non-null int64
# income_total     3152 non-null float64
# income_type      3152 non-null object
# edu_type         3152 non-null object
# family_type      3152 non-null object
# house_type       3152 non-null object
# DAYS_BIRTH       3152 non-null int64
# DAYS_EMPLOYED    3152 non-null int64
# FLAG_MOBIL       3152 non-null int64
# work_phone       3152 non-null int64
# phone            3152 non-null int64
# email            3152 non-null int64
# occyp_type       0 non-null object
# family_size      3152 non-null float64
# begin_month      3152 non-null float64
# dtypes: float64(3), int64(8), object(8)
# memory usage: 492.5+ KB

# %%
df_occyp.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 1  26458      F   N       Y          0      135000.0         State servant
# 2  26459      F   N       Y          0       69372.0               Working
# 3  26460      M   Y       N          0      112500.0  Commercial associate
# 4  26461      F   Y       Y          0      225000.0         State servant
# 5  26462      F   Y       Y          0      126000.0               Working
#
#                         edu_type           family_type         house_type  \
# 1               Higher education               Married  House / apartment
# 2  Secondary / secondary special               Married  House / apartment
# 3  Secondary / secondary special               Married  House / apartment
# 4               Higher education               Married  House / apartment
# 5  Secondary / secondary special  Single / not married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 1      -18964          -8671           1           0      1      0
# 2      -15887           -217           1           1      1      0
# 3      -19270          -2531           1           1      0      0
# 4      -17822          -9385           1           1      0      0
# 5      -18458          -2104           1           0      0      0
#
#    occyp_type  family_size  begin_month
# 1  Core staff          2.0        -36.0
# 2    Laborers          2.0        -40.0
# 3     Drivers          2.0        -41.0
# 4    Managers          2.0         -8.0
# 5  Core staff          1.0         -5.0

# %%
df_occyp.loc[df_occyp['DAYS_EMPLOYED']>0] #모두 고용된 상태
# Out:
# Empty DataFrame
# Columns: [index, gender, car, reality, child_num, income_total, income_type, edu_type, family_type, house_type, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, work_phone, phone, email, occyp_type, family_size, begin_month]
# Index: []

# %%
df_non_occyp['DAYS_EMPLOYED'].value_counts()
#양수인 부분은 이미 0으로 전환
# Out:
#  0       1697
# -422        9
# -7627       9
# -3243       9
# -3993       9
# -2014       8
# -4943       8
# -302        8
# -7369       7
# -1160       7
# -2330       7
# -2481       7
# -1466       7
# -5521       7
# -137        6
# -1661       6
# -2057       6
# -3668       6
# -1202       6
# -2908       6
# -200        6
# -218        6
# -857        6
# -135        6
# -2987       6
# -3488       6
# -2753       6
# -1871       6
# -4834       6
# -229        5
#          ...
# -2268       1
# -4335       1
# -259        1
# -2324       1
# -4033       1
# -1976       1
# -1682       1
# -1962       1
# -5782       1
# -1688       1
# -6499       1
# -1716       1
# -5818       1
# -3779       1
# -5864       1
# -3837       1
# -3839       1
# -1806       1
# -6608       1
# -231        1
# -1816       1
# -5948       1
# -3907       1
# -3913       1
# -3931       1
# -3933       1
# -4509       1
# -8071       1
# -1662       1
# -4082       1
# Name: DAYS_EMPLOYED, Length: 678, dtype: int64

# %%
df_non_occyp.loc[df_non_occyp['DAYS_EMPLOYED']!=0]['income_type'].value_counts()
#소득분류 분포(고용된 사람 중)
# Out:
# Working                 885
# Commercial associate    412
# State servant           156
# Pensioner                 2
# Name: income_type, dtype: int64

# %%
df_non_occyp.loc[df_non_occyp['DAYS_EMPLOYED']==0]['income_type'].value_counts()
#전원 연금을 받는 사람들이다
# Out:
# Pensioner    1697
# Name: income_type, dtype: int64

# %%
print(df_occyp.shape,df_non_occyp.shape)
# Out:
# (6848, 19) (3152, 19)

# %%
df_non_occyp.loc[(df_non_occyp['DAYS_EMPLOYED']==0),'occyp_type']='inocc'

# %%
df_non_occyp['income_type'].value_counts().plot(kind='bar')
#결측치가 들어간 데이터 내 소득 분류

# %%
df_occyp['income_type'].value_counts().plot(kind='bar')

# %%
df_non_occyp.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       1455
# family_size         0
# begin_month         0
# dtype: int64

# %%
test_data=pd.concat([df_non_occyp,df_occyp])

# %%
test_data.head()
# Out:
#     index gender car reality  child_num  income_total           income_type  \
# 0   26457      M   Y       N          0      112500.0             Pensioner
# 6   26463      F   N       Y          0      585000.0  Commercial associate
# 7   26464      F   N       Y          0      141750.0             Pensioner
# 8   26465      F   N       N          0      225000.0               Working
# 10  26467      F   N       Y          0       90000.0             Pensioner
#
#                          edu_type           family_type         house_type  \
# 0   Secondary / secondary special        Civil marriage  House / apartment
# 6   Secondary / secondary special               Married  House / apartment
# 7                Higher education               Married  House / apartment
# 8   Secondary / secondary special  Single / not married  House / apartment
# 10  Secondary / secondary special                 Widow  House / apartment
#
#     DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0       -21990              0           1           0      1      0
# 6       -18858          -2010           1           0      1      0
# 7       -20345              0           1           0      1      0
# 8       -19316          -4451           1           1      1      0
# 10      -21056              0           1           0      1      0
#
#    occyp_type  family_size  begin_month
# 0       inocc          2.0        -60.0
# 6         NaN          2.0         -1.0
# 7       inocc          2.0        -10.0
# 8         NaN          1.0        -23.0
# 10      inocc          1.0        -47.0

# %%
label_encoder=preprocessing.LabelEncoder()
test_data['gender'] = test_data['gender'].replace(['F','M'],[0,1])
test_data['car'] = test_data['car'].replace(['N','Y'],[0,1])
test_data['reality'] = test_data['reality'].replace(['N','Y'],[0,1])
test_data['income_type']=label_encoder.fit_transform(test_data['income_type'])
#################################################################
test_data['edu_type']=label_encoder.fit_transform(test_data['edu_type'])
########################################################################
test_data['family_type']=label_encoder.fit_transform(test_data['family_type'])

# %%
########################################################################
test_data['house_type']=label_encoder.fit_transform(test_data['house_type'])
########################################################################

# %%
test_data.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 0   26457       1    1        0          0      112500.0            1
# 6   26463       0    0        1          0      585000.0            0
# 7   26464       0    0        1          0      141750.0            1
# 8   26465       0    0        0          0      225000.0            4
# 10  26467       0    0        1          0       90000.0            1
#
#     edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0          4            0           1      -21990              0           1
# 6          4            1           1      -18858          -2010           1
# 7          1            1           1      -20345              0           1
# 8          4            3           1      -19316          -4451           1
# 10         4            4           1      -21056              0           1
#
#     work_phone  phone  email occyp_type  family_size  begin_month
# 0            0      1      0      inocc          2.0        -60.0
# 6            0      1      0        NaN          2.0         -1.0
# 7            0      1      0      inocc          2.0        -10.0
# 8            1      1      0        NaN          1.0        -23.0
# 10           0      1      0      inocc          1.0        -47.0

# %%
null_data_t=test_data.loc[test_data['occyp_type'].isnull()]
fill_data_t=test_data.dropna()

# %%
null_data_t.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 6   26463       0    0        1          0      585000.0            0
# 8   26465       0    0        0          0      225000.0            4
# 38  26495       1    1        0          1      225000.0            4
# 53  26510       0    0        1          0      112500.0            0
# 56  26513       1    1        1          0       90000.0            4
#
#     edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 6          4            1           1      -18858          -2010           1
# 8          4            3           1      -19316          -4451           1
# 38         4            3           1      -13902          -1589           1
# 53         1            1           1      -17472          -1202           1
# 56         4            1           5      -11176          -3079           1
#
#     work_phone  phone  email occyp_type  family_size  begin_month
# 6            0      1      0        NaN          2.0         -1.0
# 8            1      1      0        NaN          1.0        -23.0
# 38           0      1      0        NaN          2.0        -21.0
# 53           1      1      0        NaN          2.0        -48.0
# 56           1      0      0        NaN          2.0        -44.0

# %%
fill_data_t.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 0   26457       1    1        0          0      112500.0            1
# 7   26464       0    0        1          0      141750.0            1
# 10  26467       0    0        1          0       90000.0            1
# 13  26470       0    0        1          0       90000.0            1
# 14  26471       0    0        1          0      202500.0            1
#
#     edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0          4            0           1      -21990              0           1
# 7          1            1           1      -20345              0           1
# 10         4            4           1      -21056              0           1
# 13         4            2           1      -21299              0           1
# 14         4            1           1      -22936              0           1
#
#     work_phone  phone  email occyp_type  family_size  begin_month
# 0            0      1      0      inocc          2.0        -60.0
# 7            0      1      0      inocc          2.0        -10.0
# 10           0      1      0      inocc          1.0        -47.0
# 13           0      0      0      inocc          1.0        -44.0
# 14           0      0      0      inocc          2.0        -55.0

# %%
test_data.shape
# Out:
# (10000, 19)

# %%
print(fill_data_t.shape,null_data_t.shape)
# Out:
# (8545, 19) (1455, 19)

# %%
fill_data_t['occyp_type_l']=label_encoder.fit_transform(fill_data_t['occyp_type'])

# %%
fill_data_t.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month', 'occyp_type_l'],
#       dtype='object')

# %%
lin_reg = linear_model.LinearRegression()
x=fill_data_t[fill_data_t.columns.drop(['index','occyp_type','occyp_type_l'])]
#employeed(0,1)을 넣지 않고 days_employed에서 양수값을 0으로 처리한 상태에서 재시도
#라벨링한 occyp_type_l는 종속변수로 사용
y=fill_data_t['occyp_type_l']#라벨링 상태
lin_reg_model = lin_reg.fit(x, y)

# %%
x.shape
# Out:
# (8545, 17)

# %%
null_data_t.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'begin_month'],
#       dtype='object')

# %%
x_test=null_data_t[null_data_t.columns.drop(['index','occyp_type'])]
y_test=null_data_t['occyp_type']
y_test=lin_reg.predict(x_test)#결측치가 있는 데이터에 대입
null_data_t['occyp_type']=y_test

# %%
null_data_t.head()
# Out:
#     index  gender  car  reality  child_num  income_total  income_type  \
# 6   26463       0    0        1          0      585000.0            0
# 8   26465       0    0        0          0      225000.0            4
# 38  26495       1    1        0          1      225000.0            4
# 53  26510       0    0        1          0      112500.0            0
# 56  26513       1    1        1          0       90000.0            4
#
#     edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 6          4            1           1      -18858          -2010           1
# 8          4            3           1      -19316          -4451           1
# 38         4            3           1      -13902          -1589           1
# 53         1            1           1      -17472          -1202           1
# 56         4            1           5      -11176          -3079           1
#
#     work_phone  phone  email  occyp_type  family_size  begin_month
# 6            0      1      0   12.543801          2.0         -1.0
# 8            1      1      0    8.721262          1.0        -23.0
# 38           0      1      0    8.338820          2.0        -21.0
# 53           1      1      0   11.187210          2.0        -48.0
# 56           1      0      0    4.401830          2.0        -44.0

# %%
fill_data_t['occyp_type'].value_counts()
# Out:
# Laborers                 1699
# inocc                    1697
# Sales staff               946
# Core staff                945
# Managers                  845
# Drivers                   563
# Medicine staff            343
# High skill tech staff     343
# Accountants               339
# Cooking staff             198
# Security staff            168
# Cleaning staff            148
# Private service staff     101
# Secretaries                54
# Waiters/barmen staff       50
# Low-skill Laborers         48
# HR staff                   23
# IT staff                   19
# Realty agents              16
# Name: occyp_type, dtype: int64

# %%
fill_data_t['occyp_type_l'].value_counts()
# Out:
# 8     1699
# 18    1697
# 14     946
# 3      945
# 10     845
# 4      563
# 11     343
# 6      343
# 0      339
# 2      198
# 16     168
# 1      148
# 12     101
# 15      54
# 17      50
# 9       48
# 5       23
# 7       19
# 13      16
# Name: occyp_type_l, dtype: int64

# %%
np.round(y_test,0)
# Out:
# array([13.,  9.,  8., ...,  6.,  6., 12.])

# %%
null_data_t['occyp_type']=np.round(null_data_t['occyp_type'],0)

# %%
null_data_t['occyp_type'].describe() #3이 최소 16이 최대
# Out:
# count    1455.000000
# mean        8.526460
# std         2.367061
# min         3.000000
# 25%         7.000000
# 50%         8.000000
# 75%        10.000000
# max        16.000000
# Name: occyp_type, dtype: float64

# %%
null_data_t['occyp_type'].value_counts()
# Out:
# 9.0     241
# 7.0     222
# 8.0     209
# 6.0     196
# 11.0    154
# 10.0    143
# 12.0     93
# 5.0      87
# 4.0      35
# 13.0     33
# 14.0     30
# 15.0      8
# 16.0      3
# 3.0       1
# Name: occyp_type, dtype: int64

# %%
fill_data_t['occyp_type'].unique()
# Out:
# array(['inocc', 'Core staff', 'Laborers', 'Drivers', 'Managers',
#        'Sales staff', 'Cleaning staff', 'Accountants', 'Cooking staff',
#        'Medicine staff', 'Realty agents', 'Waiters/barmen staff',
#        'Private service staff', 'High skill tech staff',
#        'Low-skill Laborers', 'Security staff', 'Secretaries', 'HR staff',
#        'IT staff'], dtype=object)

# %%
fill_data_t['occyp_type_l'].unique()
# Out:
# array([18,  3,  8,  4, 10, 14,  1,  0,  2, 11, 13, 17, 12,  6,  9, 16, 15,
#         5,  7], dtype=int64)

# %%
null_data_t.loc[null_data_t['occyp_type']==16.0,'occyp_type']='Security staff'
null_data_t.loc[null_data_t['occyp_type']==3.0,'occyp_type']='Core staff'
null_data_t.loc[null_data_t['occyp_type']==4.0,'occyp_type']='Drivers'
null_data_t.loc[null_data_t['occyp_type']==5.0,'occyp_type']='HR staff'
null_data_t.loc[null_data_t['occyp_type']==6.0,'occyp_type']='High skill tech staff'
null_data_t.loc[null_data_t['occyp_type']==7.0,'occyp_type']='IT staff'
null_data_t.loc[null_data_t['occyp_type']==8.0,'occyp_type']='Laborers'
null_data_t.loc[null_data_t['occyp_type']==9.0,'occyp_type']='Low-skill Laborers'
null_data_t.loc[null_data_t['occyp_type']==10.0,'occyp_type']='Managers'
null_data_t.loc[null_data_t['occyp_type']==11.0,'occyp_type']='Medicine staff'
null_data_t.loc[null_data_t['occyp_type']==12.0,'occyp_type']='Private service staff'
null_data_t.loc[null_data_t['occyp_type']==13.0,'occyp_type']='Realty agents'
null_data_t.loc[null_data_t['occyp_type']==14.0,'occyp_type']='Sales staff'
null_data_t.loc[null_data_t['occyp_type']==15.0,'occyp_type']='Secretaries'

# %%
fill_data_t['occyp_type'].value_counts().plot(kind='bar')

# %%
null_data_t['occyp_type'].value_counts().plot(kind='bar')

# %%
fill_data_t=fill_data_t.drop('occyp_type_l',axis=1)

# %%
df_t=pd.concat([null_data_t,fill_data_t]).sort_values(by='index')
df_t.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0  26457       1    1        0          0      112500.0            1
# 1  26458       0    0        1          0      135000.0            2
# 2  26459       0    0        1          0       69372.0            4
# 3  26460       1    1        0          0      112500.0            0
# 4  26461       0    1        1          0      225000.0            2
#
#    edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         4            0           1      -21990              0           1
# 1         1            1           1      -18964          -8671           1
# 2         4            1           1      -15887           -217           1
# 3         4            1           1      -19270          -2531           1
# 4         1            1           1      -17822          -9385           1
#
#    work_phone  phone  email  occyp_type  family_size  begin_month
# 0           0      1      0       inocc          2.0        -60.0
# 1           0      1      0  Core staff          2.0        -36.0
# 2           1      1      0    Laborers          2.0        -40.0
# 3           1      0      0     Drivers          2.0        -41.0
# 4           1      0      0    Managers          2.0         -8.0

# %% [markdown]
# ## 모델링

# %%
data=df.copy()
data=data.drop('employeed',axis=1)
data.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0      0       0    0        0          0      202500.0            0
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
#
#    edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         1            1           2      -13899          -4709           1
# 1         4            0           1      -11380          -1540           1
# 2         1            1           1      -19087          -4434           1
# 3         4            1           1      -15088          -2092           1
# 4         1            1           1      -15037          -2105           1
#
#    work_phone  phone  email   occyp_type  family_size  begin_month  credit
# 0           0      0      0     Laborers          2.0         -6.0     1.0
# 1           0      0      1     Laborers          3.0         -5.0     1.0
# 2           0      1      0     Managers          2.0        -22.0     2.0
# 3           0      1      0  Sales staff          2.0        -37.0     0.0
# 4           0      0      0     Managers          2.0        -26.0     2.0

# %%
data['occyp_type']=label_encoder.fit_transform(data['occyp_type'])
data.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0      0       0    0        0          0      202500.0            0
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
#
#    edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         1            1           2      -13899          -4709           1
# 1         4            0           1      -11380          -1540           1
# 2         1            1           1      -19087          -4434           1
# 3         4            1           1      -15088          -2092           1
# 4         1            1           1      -15037          -2105           1
#
#    work_phone  phone  email  occyp_type  family_size  begin_month  credit
# 0           0      0      0           8          2.0         -6.0     1.0
# 1           0      0      1           8          3.0         -5.0     1.0
# 2           0      1      0          10          2.0        -22.0     2.0
# 3           0      1      0          14          2.0        -37.0     0.0
# 4           0      0      0          10          2.0        -26.0     2.0

# %%
train_x=data.drop(['credit','index'],axis=1)
train_y=data[['credit']]
print(train_x.shape,train_y.shape)
# Out:
# (26457, 18) (26457, 1)

# %%
train_x.head()
# Out:
#    gender  car  reality  child_num  income_total  income_type  edu_type  \
# 0       0    0        0          0      202500.0            0         1
# 1       0    0        1          1      247500.0            0         4
# 2       1    1        1          0      450000.0            4         1
# 3       0    0        1          0      202500.0            0         4
# 4       0    1        1          0      157500.0            2         1
#
#    family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# 0            1           2      -13899          -4709           1           0
# 1            0           1      -11380          -1540           1           0
# 2            1           1      -19087          -4434           1           0
# 3            1           1      -15088          -2092           1           0
# 4            1           1      -15037          -2105           1           0
#
#    phone  email  occyp_type  family_size  begin_month
# 0      0      0           8          2.0         -6.0
# 1      0      1           8          3.0         -5.0
# 2      1      0          10          2.0        -22.0
# 3      1      0          14          2.0        -37.0
# 4      0      0          10          2.0        -26.0

# %%
test_x=df_t.copy()

# %%
test_x['occyp_type']=label_encoder.fit_transform(test_x['occyp_type'])
test_x.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0  26457       1    1        0          0      112500.0            1
# 1  26458       0    0        1          0      135000.0            2
# 2  26459       0    0        1          0       69372.0            4
# 3  26460       1    1        0          0      112500.0            0
# 4  26461       0    1        1          0      225000.0            2
#
#    edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         4            0           1      -21990              0           1
# 1         1            1           1      -18964          -8671           1
# 2         4            1           1      -15887           -217           1
# 3         4            1           1      -19270          -2531           1
# 4         1            1           1      -17822          -9385           1
#
#    work_phone  phone  email  occyp_type  family_size  begin_month
# 0           0      1      0          18          2.0        -60.0
# 1           0      1      0           3          2.0        -36.0
# 2           1      1      0           8          2.0        -40.0
# 3           1      0      0           4          2.0        -41.0
# 4           1      0      0          10          2.0         -8.0

# %%
test_x=test_x.drop('index',axis=1)
test_x.head()
# Out:
#    gender  car  reality  child_num  income_total  income_type  edu_type  \
# 0       1    1        0          0      112500.0            1         4
# 1       0    0        1          0      135000.0            2         1
# 2       0    0        1          0       69372.0            4         4
# 3       1    1        0          0      112500.0            0         4
# 4       0    1        1          0      225000.0            2         1
#
#    family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# 0            0           1      -21990              0           1           0
# 1            1           1      -18964          -8671           1           0
# 2            1           1      -15887           -217           1           1
# 3            1           1      -19270          -2531           1           1
# 4            1           1      -17822          -9385           1           1
#
#    phone  email  occyp_type  family_size  begin_month
# 0      1      0          18          2.0        -60.0
# 1      1      0           3          2.0        -36.0
# 2      1      0           8          2.0        -40.0
# 3      0      0           4          2.0        -41.0
# 4      0      0          10          2.0         -8.0

# %%
print(train_x.shape,test_x.shape,train_y.shape)
# Out:
# (26457, 18) (10000, 18) (26457, 1)

# %% [markdown]
# ### Xgboost

# %%
sc = StandardScaler()#표준화
x_train_df=train_x.copy()
y_train_df=train_y.copy()

X=x_train_df.values
Y=y_train_df.values

x_train = sc.fit_transform(X)

# %%
print(x_train[0])
# Out:
# [-0.70356176 -0.78246318 -1.43762552 -0.5735993   0.1491363  -1.37957168
#  -1.56352825 -0.38558347  0.76270405  0.49007478 -1.05922745  0.
#  -0.53841734 -0.64570461 -0.31693724 -0.28104931 -0.21473529  1.21523077]

# %%
x_test=test_x.copy()
x_test=x_test.values
x_test=sc.transform(x_test)

# %%
x_test[0]
# Out:
# array([ 1.42133933,  1.27801541, -1.43762552, -0.5735993 , -0.73428677,
#        -0.80349087,  0.67264734, -1.43543237, -0.29633138, -1.43566162,
#         0.92761212,  0.        , -0.53841734,  1.54869577, -0.31693724,
#         1.59566293, -0.21473529, -2.04578904])

# %% [markdown]
# ### 표준화

# %%
X_train, X_val, y_train, y_val = train_test_split(x_train, train_y, 
                                                    stratify=train_y, test_size=0.25)

print("Train set: ")
print(X_train.shape)
print(y_train.shape)
print("===========")
print("Validation set: ")
print(X_val.shape)
print(y_val.shape)

xgb=XGBClassifier(n_estimators=1000)
xgb.fit(x_train,train_y)

y_pred=xgb.predict_proba(X_val) 

print(f"log_loss: {log_loss(to_categorical(y_val['credit']), y_pred)}")
# Out:
# Train set:
# (19842, 18)
# (19842, 1)
# ===========
# Validation set:
# (6615, 18)
# (6615, 1)
# log_loss: 0.6595067437552338

# %%
#xgboost(표준화)
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=55)
        
outcomes = []
sub = np.zeros((test_x.shape[0],3))
for n_fold, (train_index, val_index)  in enumerate(folds.split(x_train, train_y)):
    X_train, X_val = x_train[train_index], x_train[val_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]
    xgb=XGBClassifier(n_estimators=1000)
    xgb.fit(X_train, y_train)
    predictions = xgb.predict_proba(X_val)
    y_val_onehot = pd.get_dummies(y_val)

    sub += xgb.predict_proba(x_test)

    logloss = log_loss(y_val_onehot, predictions)
    outcomes.append(logloss)

# %%
print(np.mean(outcomes))
# Out:
# 0.7554255586533906

# %% [markdown]
# ### 표준화x

# %%
#xgboost(표준화x)
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=55)
        
outcomes = []
sub = np.zeros((test_x.shape[0],3))
for n_fold, (train_index, val_index)  in enumerate(folds.split(train_x, train_y)):
    X_train, X_val = train_x.iloc[train_index], train_x.iloc[val_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]
    xgb=XGBClassifier(n_estimators=1000)
    xgb.fit(X_train, y_train)
    predictions = xgb.predict_proba(X_val)
    y_val_onehot = pd.get_dummies(y_val)

    sub += xgb.predict_proba(test_x)

    logloss = log_loss(y_val_onehot, predictions)
    outcomes.append(logloss)

sub = sub / 5
xg_sc_logloss=np.mean(outcomes)
print(xg_sc_logloss)
# Out:
# 0.7554281170524562

# %% [markdown]
# ## LightGBM

# %%
#표준화x
X_train, X_val, y_train, y_val = train_test_split(train_x, train_y,stratify=train_y, test_size=0.25) 
                                                    
print("Train set: ")
print(X_train.shape)
print(y_train.shape)
print("===========")
print("Validation set: ")
print(X_val.shape)
print(y_val.shape)

lgbm = LGBMClassifier(n_estimators=1000)
lgbm.fit(X_train, y_train)
y_pred=lgbm.predict_proba(X_val)

print(f"log_loss: {log_loss(to_categorical(y_val['credit']), y_pred)}")
# Out:
# Train set:
# (19842, 18)
# (19842, 1)
# ===========
# Validation set:
# (6615, 18)
# (6615, 1)
# log_loss: 0.777095740864425

# %%
fig,ax=plt.subplots(figsize=(10,12))
plot_importance(lgbm,ax=ax)

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=55)
        
outcomes = []
sub = np.zeros((test_x.shape[0],3))
for n_fold, (train_index, val_index)  in enumerate(folds.split(train_x, train_y)):
    X_train, X_val = train_x.iloc[train_index], train_x.iloc[val_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]
    lgbm = LGBMClassifier(n_estimators=1000)
    lgbm.fit(X_train, y_train)
    predictions = lgbm.predict_proba(X_val)
    y_val_onehot = pd.get_dummies(y_val)

    sub += lgbm.predict_proba(test_x)

    logloss = log_loss(y_val_onehot, predictions)
    outcomes.append(logloss)

sub = sub / 5
   
lg_logloss=np.mean(outcomes)#logloss의 평균
print(lg_logloss)
# Out:
# 0.7602560039804878

# %%
#표준화 후
X_train, X_val, y_train, y_val = train_test_split(x_train, train_y,stratify=train_y, test_size=0.25) 
                                                    
print("Train set: ")
print(X_train.shape)
print(y_train.shape)
print("===========")
print("Validation set: ")
print(X_val.shape)
print(y_val.shape)

lgbm = LGBMClassifier(n_estimators=1000)
lgbm.fit(X_train, y_train)
y_pred=lgbm.predict_proba(X_val)

print(f"log_loss: {log_loss(to_categorical(y_val['credit']), y_pred)}")
# Out:
# Train set:
# (19842, 18)
# (19842, 1)
# ===========
# Validation set:
# (6615, 18)
# (6615, 1)
# log_loss: 0.7744379232744685

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=55)
        
outcomes = []
sub = np.zeros((test_x.shape[0],3))
for n_fold, (train_index, val_index)  in enumerate(folds.split(x_train, train_y)):
    X_train, X_val = x_train[train_index], x_train[val_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]
    lgbm = LGBMClassifier(n_estimators=1000)
    lgbm.fit(X_train, y_train)
    predictions = lgbm.predict_proba(X_val)
    y_val_onehot = pd.get_dummies(y_val)

    sub += lgbm.predict_proba(x_test)

    logloss = log_loss(y_val_onehot, predictions)
    outcomes.append(logloss)

sub = sub / 5

# %%
lg_sc_logloss=np.mean(outcomes)#logloss의 평균

# %%
print(lg_sc_logloss)
# Out:
# 0.760487002427386

# %% [markdown]
# - XGBOOST(k-fold 기준)
#  - 표준화:0.7554255586533906
#  - 표준화x:0.7554281170524562 (k-fold 기준)
# - LightGBM(k-fold 기준)
#  - 표준화: 0.760487002427386
#  - 표준화x:0.7602560039804878

# %% [markdown]
# ### 변수별 EDA

# %%
#중복값 제거 없이 실행
df_train.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0      -13899          -4709           1           0      0      0
# 1      -11380          -1540           1           0      0      1
# 2      -19087          -4434           1           0      1      0
# 3      -15088          -2092           1           0      1      0
# 4      -15037          -2105           1           0      0      0
#
#     occyp_type  family_size  begin_month  credit
# 0          NaN          2.0         -6.0     1.0
# 1     Laborers          3.0         -5.0     1.0
# 2     Managers          2.0        -22.0     2.0
# 3  Sales staff          2.0        -37.0     0.0
# 4     Managers          2.0        -26.0     2.0

# %%
# 성별 분포
plt.figure(figsize=(10,5))
sns.countplot('gender',data=df_train)#여성이 더 많은 편이다.
plt.show()

# %%
# 성별별 신용도 분포
plt.figure(figsize=(10,5))
sns.countplot('gender',hue='credit',data=df_train)
plt.show()
#남성과 여성 둘 다 2.0대가 높아 신용도가 낮은 편이다.
#하지만 주로 여성에서 많이 나타나는 편이다.

# %%
#신용도 그래프
plt.figure(figsize=(10,5))
sns.countplot('credit',data=df_train)
plt.show()
#2.0대 신용도가 많은 것으로 보아 신용도가 낮은 사람들이 많은 것으로 확인된다.

# %%
df_train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %%
len(df_train)
# Out:
# 26457

# %%
df_train['gender']=df_train['gender'].replace(['F','M'],[0,1])

# %%
df_test['gender']=df_test['gender'].replace(['F','M'],[0,1])

# %%
print('gender :')
print(df_train['gender'].value_counts())
print('------------') #여성:0,남성:1
# Out:
# gender :
# 0    17697
# 1     8760
# Name: gender, dtype: int64
# ------------

# %%
#차량 소지 여부
plt.figure(figsize=(10,5))
sns.countplot('car',data=df_train)
plt.show() #차량 미소지자가 많은 편이다.

# %%
plt.figure(figsize=(10,5)) #차량 소지자별 신용도
sns.countplot('car',hue='credit',data=df_train)
plt.show()
#차를 소유하지 않은 사람들 중에 2.0대가 많은 것으로 보아 신용도가 낮은 사람들 중에서는
#차량을 소지하지 않는 것으로 드러났다.

# %%
print('Having a car or not : ')
df_train['car'] = df_train['car'].replace(['N','Y'],[0,1])
df_test['car'] = df_test['car'].replace(['N','Y'],[0,1])
print(df_train['car'].value_counts())
print('--------------')
#차량 소지하지 않은 사람이 많다.
# Out:
# Having a car or not :
# 0    16410
# 1    10047
# Name: car, dtype: int64
# --------------

# %%
plt.figure(figsize=(10,5))
ax=plt.subplots()
ax=sns.countplot('reality',data=df_train)
ax2=plt.subplots()
ax2=sns.countplot('reality',hue='credit',data=df_train)
#부동산 소유자가 많은 편으로 credit은 2.0으로 갈수록 많다.

# %%
print('Having house reality or not: ')
df_train['reality'] = df_train['reality'].replace(['N','Y'],[0,1])
df_test['reality'] = df_test['reality'].replace(['N','Y'],[0,1])
print(df_train['reality'].value_counts())
print('--------------')#부동산 소유자들이 더 많다
# Out:
# Having house reality or not:
# 1    17830
# 0     8627
# Name: reality, dtype: int64
# --------------

# %%
figure,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2)
figure.set_size_inches(20,16)
g=sns.countplot(data=df_train, x="income_type",  ax=ax1)
g=sns.countplot(data=df_train, x="edu_type",  ax=ax2)
g.set_xticklabels(g.get_xticklabels(), rotation=20,
                  horizontalalignment='right',
                  fontweight='light',
                  fontsize='x-small'
                 )
g=sns.countplot(data=df_train, x="family_type", ax=ax3)
g=sns.countplot(data=df_train, x="house_type",ax=ax4)
g.set_xticklabels(g.get_xticklabels(), rotation=20,
                  horizontalalignment='right',
                  fontweight='light',
                  fontsize='x-small'
                 )
plt.show()

# %%
figure,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2)
figure.set_size_inches(20,15)
sns.countplot(data=df_train, x="income_type", hue='credit', ax=ax1)
g=sns.countplot(data=df_train, x="edu_type", hue='credit',ax=ax2)
g.set_xticklabels(g.get_xticklabels(), rotation=20,
                  horizontalalignment='right',
                  fontweight='light',
                  fontsize='x-small'
                 )
sns.countplot(data=df_train, x="family_type",hue='credit', ax=ax3)
g=sns.countplot(data=df_train, x="house_type",hue='credit', ax=ax4)
g.set_xticklabels(g.get_xticklabels(), rotation=20,
                  horizontalalignment='right',
                  fontweight='light',
                  fontsize='x-small'
                 )
plt.show()
#회사원,중&고등학생,혼인,아파트에 사는 사람들이 신용도가 낮은 편이다.

# %%
print(df_train['income_type'].unique())
print(df_train['edu_type'].unique())
print(df_train['family_type'].unique())
print(df_train['house_type'].unique())
# Out:
# ['Commercial associate' 'Working' 'State servant' 'Pensioner' 'Student']
# ['Higher education' 'Secondary / secondary special' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# ['Married' 'Civil marriage' 'Separated' 'Single / not married' 'Widow']
# ['Municipal apartment' 'House / apartment' 'With parents'
#  'Co-op apartment' 'Rented apartment' 'Office apartment']

# %%
#라벨화
label_encoder=preprocessing.LabelEncoder()
df_train['income_type']=label_encoder.fit_transform(df_train['income_type'])
df_test['income_type']=label_encoder.transform(df_test['income_type'])
#################################################################
df_train['edu_type']=label_encoder.fit_transform(df_train['edu_type'])
df_test['edu_type']=label_encoder.transform(df_test['edu_type'])
########################################################################
df_train['family_type']=label_encoder.fit_transform(df_train['family_type'])
df_test['family_type']=label_encoder.transform(df_test['family_type'])
########################################################################
df_train['house_type']=label_encoder.fit_transform(df_train['house_type'])
df_test['house_type']=label_encoder.transform(df_test['house_type'])
########################################################################

# %%
df_train['occyp_type'].unique()
# Out:
# array([nan, 'Laborers', 'Managers', 'Sales staff',
#        'High skill tech staff', 'Core staff', 'Drivers', 'Medicine staff',
#        'Accountants', 'Realty agents', 'Security staff', 'Cleaning staff',
#        'Private service staff', 'Cooking staff', 'Secretaries',
#        'HR staff', 'IT staff', 'Low-skill Laborers',
#        'Waiters/barmen staff'], dtype=object)

# %%
df_train['FLAG_MOBIL'].value_counts()
# Out:
# 1    26457
# Name: FLAG_MOBIL, dtype: int64

# %%
figure,(ax1,ax2,ax3)=plt.subplots(nrows=3,ncols=1)
figure.set_size_inches(18,10)
sns.countplot(data=df_train, x="work_phone", ax=ax1)
sns.countplot(data=df_train, x="phone", ax=ax2)
sns.countplot(data=df_train, x="email", ax=ax3)
plt.show()
#휴대폰 소유를 하고 업무용 전화,전화,이메일 소유는 적은 편이다.

# %%
figure,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2)
figure.set_size_inches(18,8)

sns.countplot(data=df_train, x="FLAG_MOBIL", hue='credit', ax=ax1)
#전원 휴대폰 소지,신용등급 낮은 편
sns.countplot(data=df_train, x="work_phone", hue='credit', ax=ax2)
sns.countplot(data=df_train, x="phone",hue='credit', ax=ax3)
sns.countplot(data=df_train, x="email",hue='credit', ax=ax4)
plt.show()
#업무용 전화 소유 여부가 많고 전화,이메일 소유하지 않은 사람 중에서 신용이 낮은 사람이 많다.

# %%
print('Having a phone or not: ')
print(df_train['phone'].value_counts())
print('--------------')
      
print('Having a email or not: ')
print(df_train['email'].value_counts())
print('--------------')
      
print('Having a work phone or not: ')
print(df_train['work_phone'].value_counts())
print('--------------')
# Out:
# Having a phone or not:
# 0    18672
# 1     7785
# Name: phone, dtype: int64
# --------------
# Having a email or not:
# 0    24042
# 1     2415
# Name: email, dtype: int64
# --------------
# Having a work phone or not:
# 0    20511
# 1     5946
# Name: work_phone, dtype: int64
# --------------

# %%
##연속형 변수(자녀 수)
df_train['child_num'].value_counts(sort=False).plot.bar()

# %%
#자녀가 2명 이상이면 2로 처리(보류)
df_train.loc[df_train['child_num'] >= 2,'child_num']=2
df_test.loc[df_test['child_num']>=2, 'child_num']=2

# %%
print(df_train['child_num'].value_counts())
# Out:
# 0    18340
# 1     5386
# 2     2731
# Name: child_num, dtype: int64

# %%
figure,(ax1,ax2)=plt.subplots(nrows=1,ncols=2)
figure.set_size_inches(10,5)
sns.countplot(data=df_train, x="child_num", ax=ax1)
sns.countplot(data=df_train, x="child_num",hue='credit',ax=ax2)
#자녀가 없는 회원이 제일 많고 그 중에서 신용등급이 제일 낮은 편이다.

# %%
plus_month=df_train.loc[df_train['begin_month']>=0]
plus_month['begin_month'].value_counts()
#begin_month은 0이 231임(신용카드 발급 상태 1달도 안됨)
# Out:
# 0.0    231
# Name: begin_month, dtype: int64

# %%
df_train['begin_year']=-df_train['begin_month']//12#신용카드 발급한지 몇년?
df_train['begin_year'].value_counts().plot(kind='bar')
#발급받은지 2년 이내가 많은 편이다.

# %%
df_train['begin_year'].value_counts()#4,5를 합치고 5개 구간으로
# Out:
# 0.0    6488
# 1.0    6322
# 2.0    5377
# 3.0    4643
# 4.0    3392
# 5.0     235
# Name: begin_year, dtype: int64

# %%
print(df_train['begin_year'].value_counts(bins=5,sort=False))
# Out:
# (-0.006, 1.0]    12810
# (1.0, 2.0]        5377
# (2.0, 3.0]        4643
# (3.0, 4.0]        3392
# (4.0, 5.0]         235
# Name: begin_year, dtype: int64

# %%
df_train.head()
# Out:
#    index  gender  car  reality  child_num  income_total  income_type  \
# 0      0       0    0        0          0      202500.0            0
# 1      1       0    0        1          1      247500.0            0
# 2      2       1    1        1          0      450000.0            4
# 3      3       0    0        1          0      202500.0            0
# 4      4       0    1        1          0      157500.0            2
#
#    edu_type  family_type  house_type  ...  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         1            1           2  ...          -4709           1
# 1         4            0           1  ...          -1540           1
# 2         1            1           1  ...          -4434           1
# 3         4            1           1  ...          -2092           1
# 4         1            1           1  ...          -2105           1
#
#    work_phone  phone  email   occyp_type family_size  begin_month  credit  \
# 0           0      0      0          NaN         2.0         -6.0     1.0
# 1           0      0      1     Laborers         3.0         -5.0     1.0
# 2           0      1      0     Managers         2.0        -22.0     2.0
# 3           0      1      0  Sales staff         2.0        -37.0     0.0
# 4           0      0      0     Managers         2.0        -26.0     2.0
#
#    begin_year
# 0         0.0
# 1         0.0
# 2         1.0
# 3         3.0
# 4         2.0
#
# [5 rows x 21 columns]

# %%
df_train['age']=-df_train['DAYS_BIRTH']//365

# %%
#신용카드를 사용한 사람들의 연령층
ax=plt.subplots()
ax=sns.distplot(df_train['age'],kde=True)
ax.set_title('Age histogram')
ax.set_xlabel('Age')
#20대 초반에서 60대 후반까지 분포한다.
# Out:
# Text(0.5, 0, 'Age')

# %%
print(df_train['age'].value_counts(bins=5,sort=False))
# Out:
# (20.951999999999998, 30.4]    4324
# (30.4, 39.8]                  6869
# (39.8, 49.2]                  6769
# (49.2, 58.6]                  5152
# (58.6, 68.0]                  3343
# Name: age, dtype: int64

# %%
bins = list(range(20,80,10))
bins_label = [str(x)+"s" for x in bins]
print(bins_label)
# Out:
# ['20s', '30s', '40s', '50s', '60s', '70s']

# %%
df_train.describe()
# Out:
#               index        gender           car       reality     child_num  \
# count  26457.000000  26457.000000  26457.000000  26457.000000  26457.000000
# mean   13228.000000      0.331103      0.379748      0.673924      0.410024
# std     7637.622372      0.470619      0.485333      0.468784      0.669604
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     6614.000000      0.000000      0.000000      0.000000      0.000000
# 50%    13228.000000      0.000000      0.000000      1.000000      0.000000
# 75%    19842.000000      1.000000      1.000000      1.000000      1.000000
# max    26456.000000      1.000000      1.000000      1.000000      2.000000
#
#        income_total   income_type      edu_type   family_type    house_type  \
# count  2.645700e+04  26457.000000  26457.000000  26457.000000  26457.000000
# mean   1.873065e+05      2.394754      3.097592      1.367275      1.279813
# std    1.018784e+05      1.735900      1.341602      0.952536      0.944273
# min    2.700000e+04      0.000000      0.000000      0.000000      0.000000
# 25%    1.215000e+05      1.000000      1.000000      1.000000      1.000000
# 50%    1.575000e+05      4.000000      4.000000      1.000000      1.000000
# 75%    2.250000e+05      4.000000      4.000000      1.000000      1.000000
# max    1.575000e+06      4.000000      4.000000      4.000000      5.000000
#
#        ...  DAYS_EMPLOYED  FLAG_MOBIL    work_phone         phone  \
# count  ...   26457.000000     26457.0  26457.000000  26457.000000
# mean   ...   59068.750728         1.0      0.224742      0.294251
# std    ...  137475.427503         0.0      0.417420      0.455714
# min    ...  -15713.000000         1.0      0.000000      0.000000
# 25%    ...   -3153.000000         1.0      0.000000      0.000000
# 50%    ...   -1539.000000         1.0      0.000000      0.000000
# 75%    ...    -407.000000         1.0      0.000000      1.000000
# max    ...  365243.000000         1.0      1.000000      1.000000
#
#               email   family_size   begin_month        credit    begin_year  \
# count  26457.000000  26457.000000  26457.000000  26457.000000  26457.000000
# mean       0.091280      2.196848    -26.123294      1.519560      1.729145
# std        0.288013      0.916717     16.559550      0.702283      1.383778
# min        0.000000      1.000000    -60.000000      0.000000      0.000000
# 25%        0.000000      2.000000    -39.000000      1.000000      1.000000
# 50%        0.000000      2.000000    -24.000000      2.000000      2.000000
# 75%        0.000000      3.000000    -12.000000      2.000000      3.000000
# max        1.000000     20.000000      0.000000      2.000000      5.000000
#
#                 age
# count  26457.000000
# mean      43.213478
# std       11.513590
# min       21.000000
# 25%       34.000000
# 50%       42.000000
# 75%       53.000000
# max       68.000000
#
# [8 rows x 21 columns]

# %%
df_train['ages']=pd.cut(df_train['age'],bins, right=False, labels = bins_label[:-1])

# %%
df_train['ages'].unique()
# Out:
# [30s, 50s, 40s, 20s, 60s]
# Categories (5, object): [20s < 30s < 40s < 50s < 60s]

# %%
df_train['ages'].value_counts()
# Out:
# 30s    7585
# 40s    6769
# 50s    5739
# 20s    3608
# 60s    2756
# Name: ages, dtype: int64

# %%
def make_bin(variable, n):#minus 변경하고 구간화
    df_train[variable]=-df_train[variable]
    df_test[variable]=-df_test[variable]
    count, bin_dividers =np.histogram(df_train[variable], bins=n) #train의 구간화를 적용
    bin_names=[str(i) for i in range(n)]
    df_train[variable]=pd.cut(x=df_train[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    df_test[variable]=pd.cut(x=df_test[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    df_test[variable].fillna(str(0), inplace=True) #test에는 없는 것을 임의의 값으로 채움
    ##########################################################
    df_train[variable]=label_encoder.fit_transform(df_train[variable])
    df_test[variable]=label_encoder.transform(df_test[variable])

# %%
df_train['ages']=label_encoder.fit_transform(df_train['ages'])
